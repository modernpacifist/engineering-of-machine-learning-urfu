# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/modernpacifist/engineering-of-machine-learning-urfu/master/python-pro-level/Datasets/melb_data.csv', sep=',')

# %%
df.Price[15]
# Out:
# 1310000.0

# %%
df.Date[90]
# Out:
# '10/09/2016'

# %%
df.Landsize[3521]/df.Landsize[1690]
# Out:
# 2.7857142857142856

# %%
df.head(5)
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5      3067      2.0       1.0  1.0     202.0
# 1  4/02/2016       2.5      3067      2.0       1.0  0.0     156.0
# 2  4/03/2017       2.5      3067      3.0       2.0  0.0     134.0
# 3  4/03/2017       2.5      3067      3.0       2.0  1.0      94.0
# 4  4/06/2016       2.5      3067      3.0       1.0  2.0     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# ...

# %%
df.tail(5)
# Out:
#        index         Suburb        Address  Rooms Type      Price Method  \
# 13575  13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown    83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown   96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville     6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  Bedroom  Bathroom  Car  \
# 13575     Barry  26/08/2017      16.7      3150      4.0       2.0  2.0
# 13576  Williams  26/08/2017       6.8      3016      3.0       2.0  2.0
# 13577     Raine  26/08/2017       6.8      3016      3.0       2.0  4.0
# 13578   Sweeney  26/08/2017       6.8      3016      4.0       1.0  5.0
# 13579   Village  26/08/2017       6.3      3013      4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# ...

# %%
df.shape
# Out:
# (13580, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
df['Car'] = df['Car'].astype('int64')
df['Bedroom'] = df['Bedroom'].astype('int64')
df['Bathroom'] = df['Bathroom'].astype('int64')
df['Propertycount'] = df['Propertycount'].astype('int64')
df['YearBuilt'] = df['YearBuilt'].astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
df.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
df.describe().loc[:, ['Distance', 'BuildingArea', 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
df.describe(include=['object'])
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname         Coordinates
# count        12211                  13580               13580
# unique          33                      8               13097
# top       Moreland  Southern Metropolitan  -37.8361, 144.9966
# freq          1163                   4695                  12

# %%
df['Regionname'].value_counts()
# Out:
# Southern Metropolitan         4695
# Northern Metropolitan         3890
# Western Metropolitan          2948
# Eastern Metropolitan          1471
# South-Eastern Metropolitan     450
# Eastern Victoria                53
# Northern Victoria               41
# Western Victoria                32
# Name: Regionname, dtype: int64

# %%
df['Regionname'].value_counts(normalize=True)
# Out:
# Southern Metropolitan         0.345729
# Northern Metropolitan         0.286451
# Western Metropolitan          0.217084
# Eastern Metropolitan          0.108321
# South-Eastern Metropolitan    0.033137
# Eastern Victoria              0.003903
# Northern Victoria             0.003019
# Western Victoria              0.002356
# Name: Regionname, dtype: float64

# %%
df['CouncilArea'].count()
# Out:
# 12211

# %%
df
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
df['Distance']
# Out:
# 0         2.5
# 1         2.5
# 2         2.5
# 3         2.5
# 4         2.5
#          ...
# 13575    16.7
# 13576     6.8
# 13577     6.8
# 13578     6.8
# 13579     6.3
# Name: Distance, Length: 13580, dtype: float64

# %%
df['Type'].value_counts()['t']
# Out:
# 1114

# %%
df['Type'].value_counts()
# Out:
# h    9449
# u    3017
# t    1114
# Name: Type, dtype: int64

# %%
df['Regionname'].value_counts()
# Out:
# Southern Metropolitan         4695
# Northern Metropolitan         3890
# Western Metropolitan          2948
# Eastern Metropolitan          1471
# South-Eastern Metropolitan     450
# Eastern Victoria                53
# Northern Victoria               41
# Western Victoria                32
# Name: Regionname, dtype: int64

# %%
df
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
df['Address']
# Out:
# 0            85 Turner St
# 1         25 Bloomburg St
# 2            5 Charles St
# 3        40 Federation La
# 4             55a Park St
#                ...
# 13575        12 Strada Cr
# 13576       77 Merrett Dr
# 13577         83 Power St
# 13578        96 Verdon St
# 13579          6 Agnes St
# Name: Address, Length: 13580, dtype: object

# %%
df.Address
# Out:
# 0            85 Turner St
# 1         25 Bloomburg St
# 2            5 Charles St
# 3        40 Federation La
# 4             55a Park St
#                ...
# 13575        12 Strada Cr
# 13576       77 Merrett Dr
# 13577         83 Power St
# 13578        96 Verdon St
# 13579          6 Agnes St
# Name: Address, Length: 13580, dtype: object

# %%
df.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
df.Rooms.value_counts()
# Out:
# 3     5881
# 2     3648
# 4     2688
# 1      681
# 5      596
# 6       67
# 7       10
# 8        8
# 10       1
# Name: Rooms, dtype: int64

# %%
mask = ((df['Price'] > 7999990) & (df['Rooms'] > 3))
mask
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578    False
# 13579    False
# Length: 13580, dtype: bool

# %%
df[mask]
# Out:
#       index      Suburb         Address  Rooms Type      Price Method  \
# 7692   7692  Canterbury  49 Mangarra Rd      5    h  8000000.0     VB
#
#         SellerG        Date  Distance  Postcode  Bedroom  Bathroom  Car  \
# 7692  Sotheby's  13/05/2017       9.0      3126        5         5    4
#
#       Landsize  BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 7692    2079.0         464.3       1880  Boroondara   -37.8179    145.0694
#
#                  Regionname  Propertycount         Coordinates
# 7692  Southern Metropolitan           3265  -37.8179, 145.0694

# %%
df
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
df[(df['Rooms'] == 3) & (df["Method"] == 'S') & (df["Type"] == 't') & (df["SellerG"] == "Beller")]
# Out:
#       index      Suburb             Address  Rooms Type      Price Method  \
# 21       21  Abbotsford  13/11 Nicholson St      3    t   900000.0      S
# 4858   4858     Prahran       1/11 Mount St      3    t  1015000.0      S
#
#      SellerG        Date  Distance  Postcode  Bedroom  Bathroom  Car  \
# 21    Beller  18/03/2017       2.5      3067        3         2    2
# 4858  Beller  24/09/2016       4.5      3181        3         3    1
#
#       Landsize  BuildingArea  YearBuilt  CouncilArea  Lattitude  Longtitude  \
# 21         0.0         126.0       2010        Yarra   -37.8093    144.9959
# 4858       0.0         126.0       1970  Stonnington   -37.8514    144.9957
#
#                  Regionname  Propertycount         Coordinates
# 21    Northern Metropolitan           4019  -37.8093, 144.9959
# 4858  Southern Metropolitan           7717  -37.8514, 144.9957

# %%
df[(df['Rooms'] == 3) & (df["Method"] == 'S') & (df["Type"] == 't') & (df["SellerG"] == "Beller")].shape[0]
# Out:
# 2

# %%
df[(df['Rooms'] == 3) & (df["Method"] == 'S') & (df["Type"] == 't')]['Price'].max()
# Out:
# 3475000.0

# %%
df[(df['Rooms'] == 3) & (df["Method"] == 'S') & (df["Type"] == 't')]['Price'].mean()
# Out:
# 995457.0559610706

# %%
mean_price = df[(df['Rooms'] == 3) & (df["Method"] == 'S') & (df["Type"] == 't')]['Price'].mean()
df[(df['Price'] > mean_price)]
# Out:
#        index         Suburb          Address  Rooms Type      Price Method  \
# 0          0     Abbotsford     85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford  25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford     5 Charles St      3    h  1465000.0     SP
# 4          4     Abbotsford      55a Park St      4    h  1600000.0     VB
# 6          6     Abbotsford     124 Yarra St      3    h  1876000.0      S
# ...      ...            ...              ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill     12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown    77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown      83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown     96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville       6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
df.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
three_quarter_percentile = df['Price'].quantile(0.75)
display(three_quarter_percentile)
df[(df['Price'] > three_quarter_percentile)]
# Out:
# 1330000.0
#        index             Suburb          Address  Rooms Type      Price  \
# 0          0         Abbotsford     85 Turner St      2    h  1480000.0
# 2          2         Abbotsford     5 Charles St      3    h  1465000.0
# 4          4         Abbotsford      55a Park St      4    h  1600000.0
# 6          6         Abbotsford     124 Yarra St      3    h  1876000.0
# 7          7         Abbotsford    98 Charles St      2    h  1636000.0
# ...      ...                ...              ...    ...  ...        ...
# 13557  13557        Templestowe   10 Hathaway Cl      4    h  1753000.0
# 13558  13558  Templestowe Lower      20 Airds Rd      4    h  1745000.0
# 13560  13560  Templestowe Lower   50 Caroline Dr      5    h  1400000.0
# 13562  13562          Thornbury  7 Ballantyne St      3    h  1450000.0
# 13578  13578       Williamstown     96 Verdon St      4    h  2500000.0
#
#       Method   SellerG        Date  Distance  Postcode  Bedroom  Bathroom  \
# ...

# %%
df.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
df[(df['Bathroom'] == 0)]
# Out:
#        index          Suburb          Address  Rooms Type      Price Method  \
# 139      139      Alphington      6 Naroon Rd      3    h  1485000.0     SP
# 281      281        Armadale  3/50 Denbigh Rd      2    u   546000.0     SP
# 505      505       Balaclava   5/11 Albion St      2    u   497500.0     PI
# 584      584          Balwyn   5 Shrimpton Ct      2    h  1010000.0     PI
# 913      913  Bentleigh East  579 Warrigal Rd      3    h   700000.0      S
# ...      ...             ...              ...    ...  ...        ...    ...
# 9090    9090  Caulfield East   5/33 Grange Rd      2    u   350000.0     SP
# 9917    9917        Hawthorn   1/30 Lisson Gr      2    h  1480000.0      S
# 10795  10795         Preston   24 Mitchell St      3    h  1150000.0     SP
# 10895  10895       Balaclava  9/36 The Avenue      2    u   700000.0     SP
# 11204  11204       St Albans     148 Power St      3    h   702000.0     SP
#
# ...

# %%
df.columns
# Out:
# Index(['index', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount', 'Coordinates'],
#       dtype='object')

# %%
df[(df['SellerG'] == 'Nelson') & (df['Price'] > 3000000)]
# Out:
#        index         Suburb            Address  Rooms Type      Price Method  \
# 2553    2553        Fitzroy         17 Bell St      4    h  4011000.0      S
# 2579    2579  Fitzroy North    79 Delbridge St      4    h  3400000.0      S
# 6734    6734     Aberfeldie  126 The Boulevard      4    h  3900000.0      S
# 7695    7695  Carlton North       235 Amess St      4    h  3450000.0      S
# 11023  11023        Fitzroy   122 Nicholson St      4    h  3200000.0     VB
#
#       SellerG        Date  Distance  Postcode  Bedroom  Bathroom  Car  \
# 2553   Nelson  27/11/2016       1.6      3065        4         3    2
# 2579   Nelson  14/05/2016       3.5      3068        3         2    1
# 6734   Nelson  10/12/2016       9.1      3040        4         4    4
# 7695   Nelson  13/05/2017       3.2      3054        4         2    1
# 11023  Nelson  12/08/2017       2.1      3065        4         4    0
#
#        Landsize  BuildingArea  YearBuilt    CouncilArea  Lattitude  \
# ...

# %%
df[(df['SellerG'] == 'Nelson') & (df['Price'] > 3000000)].shape[0]
# Out:
# 5

# %%
df[(df['BuildingArea'] == 0)]['Price'].min()
# Out:
# 412500.0

# %%
df[(df['Type'] == 'h') & (df['Price'] < 3000000)]['Regionname'].mode()
# Out:
# 0    Northern Metropolitan
# dtype: object

# %%
df[(df['Price'] < 1000000) & ((df['Rooms'] > 5) | (df['YearBuilt'] > 2015))]['Price'].mean()
# Out:
# 769238.6363636364

# %%
studdf = pd.read_csv('https://raw.githubusercontent.com/modernpacifist/engineering-of-machine-learning-urfu/master/python-pro-level/Datasets/students_performance.csv')

# %%
studdf
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
studdf[studdf['gender'] == 'female'].shape
# Out:
# (518, 8)

# %%
studdf.head(15)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# ..     ...            ...                         ...           ...
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# 13    male        group A                some college      standard
# 14  female        group A             master's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# ...

# %%
studdf['writing score'][155]
# Out:
# 88

# %%
studdf.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
len(studdf)
# Out:
# 1000

# %%
studdf.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
studdf.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
studdf.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
studdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
studdf.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
studdf.dtypes.value_counts()
# Out:
# object    5
# int64     3
# dtype: int64

# %%
studdf['math score'].mean()
# Out:
# 66.089

# %%
studdf['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
studdf[studdf['test preparation course'] == 'completed']['reading score'].mean()
# Out:
# 73.89385474860335

# %%
studdf[studdf['math score'] == 0].shape[0]
# Out:
# 1

# %%
studdf[studdf['lunch'] == 'standard']['math score'].mean()
# Out:
# 70.03410852713178

# %%
studdf[studdf['lunch'] == 'free/reduced']['math score'].mean()
# Out:
# 58.92112676056338

# %%
studdf[studdf['parental level of education'] == "bachelor's degree"].shape[0]/1000
# Out:
# 0.118

# %%
meanA = studdf[studdf['race/ethnicity'] == 'group A']['writing score'].median()
meanA
# Out:
# 62.0

# %%
avgC = studdf[studdf['race/ethnicity'] == 'group C']['writing score'].mean()
display(avgC)
# Out:
# 67.82758620689656

# %%
meanA - avgC
# Out:
# -5.827586206896555

# %%
melbdf = pd.read_csv('https://raw.githubusercontent.com/modernpacifist/engineering-of-machine-learning-urfu/master/python-pro-level/Datasets/melb_data_ps.csv', sep=',')

# %%
melbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melbdf.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
melbdf.head(10)
# Out:
#    index      Suburb             Address  Rooms Type      Price Method  \
# 0      0  Abbotsford        85 Turner St      2    h  1480000.0      S
# 1      1  Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 2      2  Abbotsford        5 Charles St      3    h  1465000.0     SP
# 3      3  Abbotsford    40 Federation La      3    h   850000.0     PI
# 4      4  Abbotsford         55a Park St      4    h  1600000.0     VB
# 5      5  Abbotsford      129 Charles St      2    h   941000.0      S
# 6      6  Abbotsford        124 Yarra St      3    h  1876000.0      S
# 7      7  Abbotsford       98 Charles St      2    h  1636000.0      S
# 8      8  Abbotsford  6/241 Nicholson St      1    u   300000.0      S
# 9      9  Abbotsford       10 Valiant St      2    h  1097000.0      S
#
#   SellerG       Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 0  Biggin  3/12/2016       2.5      3067        2         1    1     202.0
# ...

# %%
melbdf_copy = melbdf.copy()
melbdf_copy.head(10)
# Out:
#    index      Suburb             Address  Rooms Type      Price Method  \
# 0      0  Abbotsford        85 Turner St      2    h  1480000.0      S
# 1      1  Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 2      2  Abbotsford        5 Charles St      3    h  1465000.0     SP
# 3      3  Abbotsford    40 Federation La      3    h   850000.0     PI
# 4      4  Abbotsford         55a Park St      4    h  1600000.0     VB
# 5      5  Abbotsford      129 Charles St      2    h   941000.0      S
# 6      6  Abbotsford        124 Yarra St      3    h  1876000.0      S
# 7      7  Abbotsford       98 Charles St      2    h  1636000.0      S
# 8      8  Abbotsford  6/241 Nicholson St      1    u   300000.0      S
# 9      9  Abbotsford       10 Valiant St      2    h  1097000.0      S
#
#   SellerG       Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 0  Biggin  3/12/2016       2.5      3067        2         1    1     202.0
# ...

# %%
melbdf_copy.drop(['index', 'Coordinates'], axis=1, inplace=True)
display(melbdf_copy.head())
display(melbdf_copy.info())
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5      3067        2         1    1     202.0
# 1  4/02/2016       2.5      3067        2         1    0     156.0
# 2  4/03/2017       2.5      3067        3         2    0     134.0
# 3  4/03/2017       2.5      3067        3         2    1      94.0
# 4  4/06/2016       2.5      3067        3         1    2     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 0         126.0       1970       Yarra   -37.7996    144.9984
# ...

# %%
total_rooms = melbdf_copy['Bathroom']+melbdf_copy['Rooms']+melbdf_copy['Bedroom']

# %%
melbdf_copy['MeanRoomsSquare'] = melbdf_copy['BuildingArea'] / total_rooms
display(melbdf_copy['MeanRoomsSquare'])
# Out:
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsSquare, Length: 13580, dtype: float64

# %%
diff_area = melbdf_copy['BuildingArea'] - melbdf_copy['Landsize']
sum_area = melbdf_copy['BuildingArea'] + melbdf_copy['Landsize']
melbdf_copy['AreaRatio'] = diff_area/sum_area
display(melbdf_copy['AreaRatio'])
# Out:
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %%
melbdf_copy.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5      3067        2         1    1     202.0
# 1  4/02/2016       2.5      3067        2         1    0     156.0
# 2  4/03/2017       2.5      3067        3         2    0     134.0
# 3  4/03/2017       2.5      3067        3         2    1      94.0
# 4  4/06/2016       2.5      3067        3         1    2     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 0         126.0       1970       Yarra   -37.7996    144.9984
# ...

# %%
melbdf.columns
# Out:
# Index(['index', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount', 'Coordinates'],
#       dtype='object')

# %%
if all(item in df.columns for item in ['Suburb','Price']):
    print("yes")
# Out:
# yes

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

# %%
countries_df
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
countries_df['ppl_density'] = countries_df['population']*1000000 / countries_df['square']

# %%
countries_df
# Out:
#      country  population    square  ppl_density
# 0     Англия       56.29    133396   421.976671
# 1     Канада       38.05   9984670     3.810842
# 2        США      322.28   9826630    32.796595
# 3     Россия      146.24  17125191     8.539467
# 4    Украина       45.50    603628    75.377550
# 5   Беларусь        9.50    207600    45.761079
# 6  Казахстан       17.04   2724902     6.253436

# %%
countries_df['ppl_density'].mean()
# Out:
# 84.93080566562001

# %%
melbdf['Date']
# Out:
# 0         3/12/2016
# 1         4/02/2016
# 2         4/03/2017
# 3         4/03/2017
# 4         4/06/2016
#             ...
# 13575    26/08/2017
# 13576    26/08/2017
# 13577    26/08/2017
# 13578    26/08/2017
# 13579    26/08/2017
# Name: Date, Length: 13580, dtype: object

# %%
pd.to_datetime(melbdf['Date'], dayfirst=True)
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
melbdf.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5      3067        2         1    1     202.0
# 1  4/02/2016       2.5      3067        2         1    0     156.0
# 2  4/03/2017       2.5      3067        3         2    0     134.0
# 3  4/03/2017       2.5      3067        3         2    1      94.0
# 4  4/06/2016       2.5      3067        3         1    2     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# ...

# %%
melbdf_copy['Date'] = pd.to_datetime(melbdf_copy['Date'], dayfirst=True)
display(melbdf_copy['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
melbdf_copy.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 0 2016-12-03       2.5      3067        2         1    1     202.0
# 1 2016-02-04       2.5      3067        2         1    0     156.0
# 2 2017-03-04       2.5      3067        3         2    0     134.0
# 3 2017-03-04       2.5      3067        3         2    1      94.0
# 4 2016-06-04       2.5      3067        3         1    2     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 0         126.0       1970       Yarra   -37.7996    144.9984
# ...

# %%
melbdf_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Address          13580 non-null  object
#  2   Rooms            13580 non-null  int64
#  3   Type             13580 non-null  object
#  4   Price            13580 non-null  float64
#  5   Method           13580 non-null  object
#  6   SellerG          13580 non-null  object
#  7   Date             13580 non-null  datetime64[ns]
#  8   Distance         13580 non-null  float64
#  9   Postcode         13580 non-null  int64
#  10  Bedroom          13580 non-null  int64
#  11  Bathroom         13580 non-null  int64
#  12  Car              13580 non-null  int64
#  13  Landsize         13580 non-null  float64
#  14  BuildingArea     13580 non-null  float64
#  15  YearBuilt        13580 non-null  int64
# ...

# %%
print(melbdf_copy['Date'].dt.year.max())

print(melbdf_copy['Date'].dt.year.min())

print(melbdf_copy['Date'].dt.year.mode())
# Out:
# 2017
# 2016
# 0    2017
# dtype: int64

# %%
melbdf_copy['MonthSale'] = melbdf_copy['Date'].dt.month
display(melbdf_copy['MonthSale'].value_counts(normalize=True))
# Out:
# 5     0.149411
# 7     0.145950
# 9     0.135862
# 6     0.134757
# 8     0.114138
#         ...
# 3     0.049926
# 12    0.044698
# 10    0.040574
# 2     0.032622
# 1     0.000147
# Name: MonthSale, Length: 12, dtype: float64

# %%
delta_days = melbdf_copy['Date'] - pd.to_datetime('2016-01-01') 
display(delta_days.dt.days)
# Out:
# 0        337
# 1         34
# 2        428
# 3        428
# 4        155
#         ...
# 13575    603
# 13576    603
# 13577    603
# 13578    603
# 13579    603
# Name: Date, Length: 13580, dtype: int64

# %%
melbdf_copy['AgeBuilding'] = melbdf_copy['Date'].dt.year - melbdf_copy['YearBuilt']
display(melbdf_copy['AgeBuilding'])
# Out:
# 0         46
# 1        116
# 2        117
# 3         47
# 4          2
#         ...
# 13575     36
# 13576     22
# 13577     20
# 13578     97
# 13579     97
# Name: AgeBuilding, Length: 13580, dtype: int64

# %%
pd.datetime.__dict__
# Out:
# <ipython-input-95-2255e25f26af>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   pd.datetime.__dict__
# mappingproxy({'__repr__': <slot wrapper '__repr__' of 'datetime.datetime' objects>,
#               '__hash__': <slot wrapper '__hash__' of 'datetime.datetime' objects>,
#               '__str__': <slot wrapper '__str__' of 'datetime.datetime' objects>,
#               '__getattribute__': <slot wrapper '__getattribute__' of 'datetime.datetime' objects>,
#               '__lt__': <slot wrapper '__lt__' of 'datetime.datetime' objects>,
#               '__le__': <slot wrapper '__le__' of 'datetime.datetime' objects>,
#               '__eq__': <slot wrapper '__eq__' of 'datetime.datetime' objects>,
#               '__ne__': <slot wrapper '__ne__' of 'datetime.datetime' objects>,
#               '__gt__': <slot wrapper '__gt__' of 'datetime.datetime' objects>,
# ...

# %%
melbdf_copy['WeekdaySale'] = melbdf_copy['Date'].dt.day_name()

# %%
melbdf_copy['WeekdaySale']
# Out:
# 0        Saturday
# 1        Thursday
# 2        Saturday
# 3        Saturday
# 4        Saturday
#            ...
# 13575    Saturday
# 13576    Saturday
# 13577    Saturday
# 13578    Saturday
# 13579    Saturday
# Name: WeekdaySale, Length: 13580, dtype: object

# %%
melbdf_copy.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 0 2016-12-03       2.5      3067        2         1    1     202.0
# 1 2016-02-04       2.5      3067        2         1    0     156.0
# 2 2017-03-04       2.5      3067        3         2    0     134.0
# 3 2017-03-04       2.5      3067        3         2    1      94.0
# 4 2016-06-04       2.5      3067        3         1    2     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 0         126.0       1970       Yarra   -37.7996    144.9984
# ...

# %%
melbdf_copy[(melbdf_copy['WeekdaySale'] == 'Saturday') | (melbdf_copy['WeekdaySale'] == 'Sunday')].shape[0]
# Out:
# 12822

# %%
ufo_df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv', sep=',')

# %%
ufo_df.head(15)
# Out:
#                     City Colors Reported Shape Reported State             Time
# 0                 Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1            Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2                Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3                Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4   New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
# ..                   ...             ...            ...   ...              ...
# 10               Fontana             NaN          LIGHT    CA  8/15/1937 21:00
# 11              Waterloo             NaN       FIREBALL    AL   6/1/1939 20:00
# 12                Belton             RED         SPHERE    SC  6/30/1939 20:00
# 13                Keokuk             NaN           OVAL    IA    7/7/1939 2:00
# 14             Ludington             NaN           DISK    MI   6/1/1941 13:00
#
# [15 rows x 5 columns]

# %%
ufo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18216 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %%
ufo_df['Time'] =  pd.to_datetime(ufo_df['Time'], dayfirst=True)
display(ufo_df)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time
# 0     1930-01-06 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-01-06 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
ufo_df['Colors Reported'].fillna(False, inplace=True)
ufo_df['Shape Reported'].fillna(False, inplace=True)
display(ufo_df)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca           False       TRIANGLE    NY
# 1               Willingboro           False          OTHER    NJ
# 2                   Holyoke           False           OVAL    CO
# 3                   Abilene           False           DISK    KS
# 4      New York Worlds Fair           False          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park           False       TRIANGLE    IL
# 18237           Spirit Lake           False           DISK    IA
# 18238           Eagle River           False          False    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor           False           OVAL    FL
#
#                      Time
# 0     1930-01-06 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-01-06 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
ufo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18216 non-null  object
#  1   Colors Reported  18241 non-null  object
#  2   Shape Reported   18241 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 712.7+ KB

# %%
ufo_df[(ufo_df['Colors Reported'] != False) & (ufo_df['Shape Reported'] != False)]['Time'].dt.year
# Out:
# 12       1939
# 19       1943
# 36       1945
# 44       1946
# 82       1947
#          ...
# 18213    2000
# 18216    2000
# 18220    2000
# 18233    2000
# 18239    2000
# Name: Time, Length: 2490, dtype: int64

# %%
ufo_df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca           False       TRIANGLE    NY
# 1               Willingboro           False          OTHER    NJ
# 2                   Holyoke           False           OVAL    CO
# 3                   Abilene           False           DISK    KS
# 4      New York Worlds Fair           False          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park           False       TRIANGLE    IL
# 18237           Spirit Lake           False           DISK    IA
# 18238           Eagle River           False          False    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor           False           OVAL    FL
#
#                      Time
# 0     1930-01-06 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-01-06 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
import collections

# %%
# Holy Moly, how wrong this approach is! (2.4)
d = ufo_df[(ufo_df['Colors Reported'] != False) & (ufo_df['Shape Reported'] != False)]['Time'].dt.year

# %%
collections.Counter(d)
# Out:
# Counter({1939: 1,
#          1943: 1,
#          1945: 1,
#          1946: 1,
#          1947: 2,
#          1948: 1,
#          1949: 1,
#          1950: 2,
#          1951: 4,
#          1952: 3,
#          1953: 6,
#          1954: 4,
#          1955: 2,
#          1956: 5,
#          1957: 2,
#          1958: 1,
#          1959: 2,
#          1960: 4,
#          1961: 5,
#          1962: 6,
#          1963: 5,
#          1964: 7,
#          1965: 26,
#          1966: 20,
#          1967: 12,
#          1968: 23,
#          1969: 11,
#          1970: 13,
#          1971: 7,
#          1972: 17,
#          1973: 31,
#          1974: 29,
#          1975: 36,
#          1976: 18,
#          1977: 28,
#          1978: 33,
#          1979: 22,
#          1980: 25,
#          1981: 15,
#          1982: 23,
#          1983: 13,
#          1984: 17,
#          1985: 22,
#          1986: 24,
#          1987: 28,
#          1988: 21,
#          1989: 28,
#          1990: 26,
# ...

# %%
ufo_df.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca           False       TRIANGLE    NY
# 1           Willingboro           False          OTHER    NJ
# 2               Holyoke           False           OVAL    CO
# 3               Abilene           False           DISK    KS
# 4  New York Worlds Fair           False          LIGHT    NY
#
#                  Time
# 0 1930-01-06 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-01-06 13:00:00
# 4 1933-04-18 19:00:00

# %%
ufo_df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca           False       TRIANGLE    NY
# 1               Willingboro           False          OTHER    NJ
# 2                   Holyoke           False           OVAL    CO
# 3                   Abilene           False           DISK    KS
# 4      New York Worlds Fair           False          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park           False       TRIANGLE    IL
# 18237           Spirit Lake           False           DISK    IA
# 18238           Eagle River           False          False    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor           False           OVAL    FL
#
#                      Time
# 0     1930-01-06 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-01-06 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
nevada_ufo_df = ufo_df[ufo_df['State'] == 'NV']

# %%
display(nevada_ufo_df)
# Out:
#              City Colors Reported Shape Reported State                Time
# 76      Las Vegas           False           DISK    NV 1947-07-15 10:00:00
# 172    Nellis AFB           False           DISK    NV 1952-02-17 18:00:00
# 565        Fallon           False           OVAL    NV 1959-09-15 00:00:00
# 566     Goldfield           False          LIGHT    NV 1959-09-15 01:00:00
# 613           NaN           False           DISK    NV 1960-01-07 12:00:00
# ...           ...             ...            ...   ...                 ...
# 17447    Laughlin           False      FORMATION    NV 2000-09-16 22:00:00
# 17567   Las Vegas           False         SPHERE    NV 2000-09-30 22:25:00
# 17617   Las Vegas      RED YELLOW          OTHER    NV 2000-06-10 20:25:00
# 17890        Reno           False       TRIANGLE    NV 2000-07-11 02:15:00
# 18104   Las Vegas           False       TRIANGLE    NV 2000-10-12 17:30:00
#
# [284 rows x 5 columns]

# %%
h = nevada_ufo_df[(nevada_ufo_df['Colors Reported'] != False) | (nevada_ufo_df['Shape Reported'] != False)]['Time']

# %%
h.diff()
# Out:
# 76                      NaT
# 172      1678 days 08:00:00
# 565      2766 days 06:00:00
# 566         0 days 01:00:00
# 613       114 days 11:00:00
#                 ...
# 17447      22 days 00:00:00
# 17567      14 days 00:25:00
# 17617   -113 days +22:00:00
# 17890      30 days 05:50:00
# 18104      93 days 15:15:00
# Name: Time, Length: 245, dtype: timedelta64[ns]

# %%
melbdf
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
melbdf['Address'].nunique()
# Out:
# 13378

# %%
def get_street_type(address):
    exclude_list = ['N', 'S', 'W', 'E']
    address_list = address.split(' ')
    street_type = address_list[-1]
    if street_type in exclude_list:
        street_type = address_list[-2]
    return street_type

# %%
street_types = melbdf['Address'].apply(get_street_type)

# %%
popular_stypes = street_types.value_counts().nlargest(10).index
print(popular_stypes)
# Out:
# Index(['St', 'Rd', 'Ct', 'Dr', 'Av', 'Gr', 'Pde', 'Pl', 'Cr', 'Cl'], dtype='object')

# %%
melbdf['StreetType'] = street_types.apply(lambda x: x if x in popular_stypes else 'other')
display(melbdf['StreetType'])
# Out:
# 0           St
# 1           St
# 2           St
# 3        other
# 4           St
#          ...
# 13575       Cr
# 13576       Dr
# 13577       St
# 13578       St
# 13579       St
# Name: StreetType, Length: 13580, dtype: object

# %%
melbdf.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5      3067        2         1    1     202.0
# 1  4/02/2016       2.5      3067        2         1    0     156.0
# 2  4/03/2017       2.5      3067        3         2    0     134.0
# 3  4/03/2017       2.5      3067        3         2    1      94.0
# 4  4/06/2016       2.5      3067        3         1    2     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# ...

# %%
melbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melbdf['StreetType'].nunique()
# Out:
# 11

# %%
melbdf = melbdf.drop('Address', axis=1)

# %%
melbdf
# Out:
#        index         Suburb  Rooms Type      Price Method   SellerG  \
# 0          0     Abbotsford      2    h  1480000.0      S    Biggin
# 1          1     Abbotsford      2    h  1035000.0      S    Biggin
# 2          2     Abbotsford      3    h  1465000.0     SP    Biggin
# 3          3     Abbotsford      3    h   850000.0     PI    Biggin
# 4          4     Abbotsford      4    h  1600000.0     VB    Nelson
# ...      ...            ...    ...  ...        ...    ...       ...
# 13575  13575  Wheelers Hill      4    h  1245000.0      S     Barry
# 13576  13576   Williamstown      3    h  1031000.0     SP  Williams
# 13577  13577   Williamstown      3    h  1170000.0      S     Raine
# 13578  13578   Williamstown      4    h  2500000.0     PI   Sweeney
# 13579  13579     Yarraville      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 0       3/12/2016       2.5      3067        2         1    1     202.0
# ...

# %%
melbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13580 non-null  int64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  int64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
melbdf = pd.read_csv('https://raw.githubusercontent.com/modernpacifist/engineering-of-machine-learning-urfu/master/python-pro-level/Datasets/melb_data_ps.csv', sep=',')

# %%
melbdf['Date'] = pd.to_datetime(melbdf['Date'])

# %%
# melbdf['WeekdaySale'] = melbdf['Date'].dt.day_name()
melbdf['WeekdaySale'] = melbdf['Date'].dt.weekday

# %%
melbdf['WeekdaySale']
# Out:
# 0        5
# 1        5
# 2        0
# 3        0
# 4        2
#         ..
# 13575    5
# 13576    5
# 13577    5
# 13578    5
# 13579    5
# Name: WeekdaySale, Length: 13580, dtype: int64

# %%
def is_weekend(day):
    # if day in ['Saturday', 'Sunday']:
    if day in [5, 6]:
        return 1
    return 0

# %%
melbdf['Weekend'] = melbdf['WeekdaySale'].apply(is_weekend)

# %%
melbdf[['WeekdaySale', 'Weekend']].value_counts()
# Out:
# WeekdaySale  Weekend
# 5            1          7896
# 0            0          1779
# 6            1          1330
# 2            0          1146
# 4            0           705
# 1            0           424
# 3            0           300
# dtype: int64

# %%
melbdf[melbdf['Weekend'] == 1]['Price'].mean()
# Out:
# 1083291.6953175808

# %% [markdown]
# ## Categorial data type

# %%
melb_df = pd.read_csv('https://raw.githubusercontent.com/modernpacifist/engineering-of-machine-learning-urfu/master/python-pro-level/Datasets/melb_data.csv', sep=',')

# %%
melb_df.head(15)
# Out:
#     index      Suburb              Address  Rooms Type      Price Method  \
# 0       0  Abbotsford         85 Turner St      2    h  1480000.0      S
# 1       1  Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 2       2  Abbotsford         5 Charles St      3    h  1465000.0     SP
# 3       3  Abbotsford     40 Federation La      3    h   850000.0     PI
# 4       4  Abbotsford          55a Park St      4    h  1600000.0     VB
# ..    ...         ...                  ...    ...  ...        ...    ...
# 10     10  Abbotsford   411/8 Grosvenor St      2    u   700000.0     VB
# 11     11  Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# 12     12  Abbotsford  123/56 Nicholson St      2    u   750000.0      S
# 13     13  Abbotsford        45 William St      2    h  1172500.0      S
# 14     14  Abbotsford   7/20 Abbotsford St      1    u   441000.0     SP
#
#    SellerG        Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# ...

# %%
unique_list = []
for col in melb_df.columns:
    item = (col, melb_df[col].nunique(),melb_df[col].dtypes) 
    unique_list.append(item) 

unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)

display(unique_counts)
# Out:
#     Column_Name  Num_Unique     Type
# 0          Type           3   object
# 1        Method           5   object
# 2    Regionname           8   object
# 3         Rooms           9    int64
# 4      Bathroom           9  float64
# ..          ...         ...      ...
# 18    Lattitude        6503  float64
# 19   Longtitude        7063  float64
# 20  Coordinates       13097   object
# 21      Address       13378   object
# 22        index       13580    int64
#
# [23 rows x 3 columns]

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
max_unique_count = 150
for col in melb_df.columns:
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude:
        melb_df[col] = melb_df[col].astype('category')
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  category
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  category
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  category
# ...

# %%
melb_df['Regionname'].cat.categories
# Out:
# Index(['Eastern Metropolitan', 'Eastern Victoria', 'Northern Metropolitan',
#        'Northern Victoria', 'South-Eastern Metropolitan',
#        'Southern Metropolitan', 'Western Metropolitan', 'Western Victoria'],
#       dtype='object')

# %%
melb_df['Regionname'].cat.codes
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 13575    4
# 13576    6
# 13577    6
# 13578    6
# 13579    6
# Length: 13580, dtype: int8

# %%
melb_df['Type'] = melb_df['Type'].cat.rename_categories({
    'u': 'unit',
    't': 'townhouse',
    'h': 'house'
})

display(melb_df['Type'])
# Out:
# 0        house
# 1        house
# 2        house
# 3        house
# 4        house
#          ...
# 13575    house
# 13576    house
# 13577    house
# 13578    house
# 13579    house
# Name: Type, Length: 13580, dtype: category
# Categories (3, object): ['house', 'townhouse', 'unit']

# %%
melb_df = melb_df.drop('index', axis=1)

# %%
melb_df
# Out:
#               Suburb           Address  Rooms   Type      Price Method  \
# 0         Abbotsford      85 Turner St      2  house  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2  house  1035000.0      S
# 2         Abbotsford      5 Charles St      3  house  1465000.0     SP
# 3         Abbotsford  40 Federation La      3  house   850000.0     PI
# 4         Abbotsford       55a Park St      4  house  1600000.0     VB
# ...              ...               ...    ...    ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4  house  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3  house  1031000.0     SP
# 13577   Williamstown       83 Power St      3  house  1170000.0      S
# 13578   Williamstown      96 Verdon St      4  house  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4  house  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  Bedroom  Bathroom  Car  \
# ...

# %%
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)
display(new_houses_types)
# Out:
# 0     unit
# 1    house
# 2      NaN
# 3      NaN
# 4    house
# dtype: category
# Categories (3, object): ['house', 'townhouse', 'unit']

# %%
melb_df['Type'] = melb_df['Type'].cat.add_categories('flat')
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)
display(new_houses_types)
# Out:
# 0     unit
# 1    house
# 2     flat
# 3     flat
# 4    house
# dtype: category
# Categories (4, object): ['house', 'townhouse', 'unit', 'flat']

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  category
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  category
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13580 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  category
#  16  CouncilArea    12211 non-null  category
# ...

# %%
display(melb_df['Suburb'])
# Out:
# 0           Abbotsford
# 1           Abbotsford
# 2           Abbotsford
# 3           Abbotsford
# 4           Abbotsford
#              ...
# 13575    Wheelers Hill
# 13576     Williamstown
# 13577     Williamstown
# 13578     Williamstown
# 13579       Yarraville
# Name: Suburb, Length: 13580, dtype: object

# %%
# mount google drive
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !ls -lah
# Out:
# total 20K
# drwxr-xr-x 1 root root 4.0K Dec 28 08:20 .
# drwxr-xr-x 1 root root 4.0K Dec 28 05:39 ..
# drwxr-xr-x 4 root root 4.0K Dec 20 20:18 .config
# drwx------ 5 root root 4.0K Dec 28 08:20 gdrive
# drwxr-xr-x 1 root root 4.0K Dec 20 20:19 sample_data

# %%
citi_bike_df = pd.read_csv('/content/gdrive/MyDrive/CsvDatasets/citibike-tripdata.csv', sep=',')

# %%
citi_bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station id         299831 non-null  float64
#  3   start station name       299831 non-null  object
#  4   start station latitude   300000 non-null  float64
#  5   start station longitude  300000 non-null  float64
#  6   end station id           299831 non-null  float64
#  7   end station name         299831 non-null  object
#  8   end station latitude     300000 non-null  float64
#  9   end station longitude    300000 non-null  float64
#  10  bikeid                   300000 non-null  int64
#  11  usertype                 300000 non-null  object
#  12  birth year               300000 non-null  int64
# ...

# %%
citi_bike_df.head(20)
# Out:
#              starttime            stoptime  start station id  \
# 0   2018-09-01 0:00:05  2018-09-01 0:27:21             252.0
# 1   2018-09-01 0:00:11  2018-09-01 0:02:23             314.0
# 2   2018-09-01 0:00:21  2018-09-01 0:55:59            3142.0
# 3   2018-09-01 0:00:22  2018-09-01 0:07:39             308.0
# 4   2018-09-01 0:00:27  2018-09-01 2:21:25             345.0
# ..                 ...                 ...               ...
# 15  2018-09-01 0:01:20  2018-09-01 0:16:13            3558.0
# 16  2018-09-01 0:01:29  2018-09-01 0:20:28            3107.0
# 17  2018-09-01 0:01:33  2018-09-01 0:08:14             350.0
# 18  2018-09-01 0:01:47  2018-09-01 0:07:40            3384.0
# 19  2018-09-01 0:02:04  2018-09-01 0:06:16             350.0
#
#                  start station name  start station latitude  \
# 0      MacDougal St & Washington Sq               40.732264
# 1   Cadman Plaza West & Montague St               40.693830
# ...

# %%
citi_bike_df['start station id'].isna().sum()
# Out:
# 169

# %%
# most popular station id
citi_bike_df['start station id'].value_counts().idxmax()
# Out:
# 281.0

# %%
citi_bike_df['start station id'].mode()
# Out:
# 0    281.0
# dtype: float64

# %%
citi_bike_df['bikeid'].mode()
# Out:
# 0    33887
# dtype: int64

# %%
citi_bike_df['usertype'].value_counts()
# Out:
# Subscriber    232202
# Customer       67798
# Name: usertype, dtype: int64

# %%
subscribers_qty = citi_bike_df[citi_bike_df.usertype == 'Subscriber'].shape[0]

# %%
citi_bike_df[citi_bike_df.usertype == 'Customer'].shape[0]
# Out:
# 67798

# %%
subscribers_qty / citi_bike_df['usertype'].shape[0]
# Out:
# 0.7740066666666666

# %%
citi_bike_df['gender'].value_counts()
# Out:
# 1    183582
# 2     74506
# 0     41912
# Name: gender, dtype: int64

# %%
citi_bike_df.head(5)
# Out:
#             starttime            stoptime  start station id  \
# 0  2018-09-01 0:00:05  2018-09-01 0:27:21             252.0
# 1  2018-09-01 0:00:11  2018-09-01 0:02:23             314.0
# 2  2018-09-01 0:00:21  2018-09-01 0:55:59            3142.0
# 3  2018-09-01 0:00:22  2018-09-01 0:07:39             308.0
# 4  2018-09-01 0:00:27  2018-09-01 2:21:25             345.0
#
#                 start station name  start station latitude  \
# 0     MacDougal St & Washington Sq               40.732264
# 1  Cadman Plaza West & Montague St               40.693830
# 2                  1 Ave & E 62 St               40.761227
# 3          St James Pl & Oliver St               40.713079
# 4                  W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# 0               -73.998522           366.0    Clinton Ave & Myrtle Ave
# 1               -73.990539          3242.0  Schermerhorn St & Court St
# ...

# %%
print(citi_bike_df['start station name'].unique().size)
print(citi_bike_df['end station name'].unique().size)
# Out:
# 760
# 766

# %%
citi_bike_df['birth year'].max()
# Out:
# 2002

# %%
citi_bike_df['start station name'].value_counts()
# Out:
# Grand Army Plaza & Central Park S    1928
# Central Park S & 6 Ave               1909
# Pershing Square North                1873
# 12 Ave & W 40 St                     1845
# West St & Chambers St                1835
#                                      ...
# NYCBS Depot - GOW                      15
# Franklin Ave & Empire Blvd             11
# Railroad Ave & Kay Ave                  9
# 47 Ave & Skillman Ave                   7
# Eastern Pkwy & Washington Ave           6
# Name: start station name, Length: 759, dtype: int64

# %%
citi_bike_df.head(1)
# Out:
#             starttime            stoptime  start station id  \
# 0  2018-09-01 0:00:05  2018-09-01 0:27:21             252.0
#
#              start station name  start station latitude  \
# 0  MacDougal St & Washington Sq               40.732264
#
#    start station longitude  end station id          end station name  \
# 0               -73.998522           366.0  Clinton Ave & Myrtle Ave
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.693261             -73.968896   25577  Subscriber
#
#    birth year  gender
# 0        1980       1

# %%
citi_bike_df = citi_bike_df.drop(columns='end station id')
citi_bike_df.head(1)
citi_bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station name       299831 non-null  object
#  3   start station latitude   300000 non-null  float64
#  4   start station longitude  300000 non-null  float64
#  5   end station name         299831 non-null  object
#  6   end station latitude     300000 non-null  float64
#  7   end station longitude    300000 non-null  float64
#  8   bikeid                   300000 non-null  int64
#  9   usertype                 300000 non-null  object
#  10  birth year               300000 non-null  int64
#  11  gender                   300000 non-null  int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 27.5+ MB

# %%
def age_calculation(birth_year):
    age = 2018 - birth_year
    return age

# %%
citi_bike_df.rename(columns={'birth year': 'age'}, inplace=True)

# %%
citi_bike_df['age'] = citi_bike_df['age'].apply(age_calculation)

# %%
citi_bike_df.head(5)
# Out:
#             starttime            stoptime               start station name  \
# 0  2018-09-01 0:00:05  2018-09-01 0:27:21     MacDougal St & Washington Sq
# 1  2018-09-01 0:00:11  2018-09-01 0:02:23  Cadman Plaza West & Montague St
# 2  2018-09-01 0:00:21  2018-09-01 0:55:59                  1 Ave & E 62 St
# 3  2018-09-01 0:00:22  2018-09-01 0:07:39          St James Pl & Oliver St
# 4  2018-09-01 0:00:27  2018-09-01 2:21:25                  W 13 St & 6 Ave
#
#    start station latitude  start station longitude  \
# 0               40.732264               -73.998522
# 1               40.693830               -73.990539
# 2               40.761227               -73.960940
# 3               40.713079               -73.998512
# 4               40.736494               -73.997044
#
#              end station name  end station latitude  end station longitude  \
# 0    Clinton Ave & Myrtle Ave             40.693261             -73.968896
# ...

# %%
citi_bike_df[citi_bike_df['age'] > 60].shape[0]
# Out:
# 11837

# %%
citi_bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station name       299831 non-null  object
#  3   start station latitude   300000 non-null  float64
#  4   start station longitude  300000 non-null  float64
#  5   end station name         299831 non-null  object
#  6   end station latitude     300000 non-null  float64
#  7   end station longitude    300000 non-null  float64
#  8   bikeid                   300000 non-null  int64
#  9   usertype                 300000 non-null  object
#  10  age                      300000 non-null  int64
#  11  gender                   300000 non-null  int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 27.5+ MB

# %%
citi_bike_df['starttime'] = pd.to_datetime(citi_bike_df['starttime'])
citi_bike_df['stoptime'] = pd.to_datetime(citi_bike_df['stoptime'])

# %%
citi_bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  datetime64[ns]
#  1   stoptime                 300000 non-null  datetime64[ns]
#  2   start station name       299831 non-null  object
#  3   start station latitude   300000 non-null  float64
#  4   start station longitude  300000 non-null  float64
#  5   end station name         299831 non-null  object
#  6   end station latitude     300000 non-null  float64
#  7   end station longitude    300000 non-null  float64
#  8   bikeid                   300000 non-null  int64
#  9   usertype                 300000 non-null  object
#  10  age                      300000 non-null  int64
#  11  gender                   300000 non-null  int64
# dtypes: datetime64[ns](2), float64(4), int64(3), object(3)
# ...

# %%
citi_bike_df.head(5)
# Out:
#             starttime            stoptime               start station name  \
# 0 2018-09-01 00:00:05 2018-09-01 00:27:21     MacDougal St & Washington Sq
# 1 2018-09-01 00:00:11 2018-09-01 00:02:23  Cadman Plaza West & Montague St
# 2 2018-09-01 00:00:21 2018-09-01 00:55:59                  1 Ave & E 62 St
# 3 2018-09-01 00:00:22 2018-09-01 00:07:39          St James Pl & Oliver St
# 4 2018-09-01 00:00:27 2018-09-01 02:21:25                  W 13 St & 6 Ave
#
#    start station latitude  start station longitude  \
# 0               40.732264               -73.998522
# 1               40.693830               -73.990539
# 2               40.761227               -73.960940
# 3               40.713079               -73.998512
# 4               40.736494               -73.997044
#
#              end station name  end station latitude  end station longitude  \
# 0    Clinton Ave & Myrtle Ave             40.693261             -73.968896
# ...

# %%
citi_bike_df['trip duration'] = (citi_bike_df['stoptime'] - citi_bike_df['starttime']).dt.total_seconds()
citi_bike_df.head(5)
# Out:
#             starttime            stoptime               start station name  \
# 0 2018-09-01 00:00:05 2018-09-01 00:27:21     MacDougal St & Washington Sq
# 1 2018-09-01 00:00:11 2018-09-01 00:02:23  Cadman Plaza West & Montague St
# 2 2018-09-01 00:00:21 2018-09-01 00:55:59                  1 Ave & E 62 St
# 3 2018-09-01 00:00:22 2018-09-01 00:07:39          St James Pl & Oliver St
# 4 2018-09-01 00:00:27 2018-09-01 02:21:25                  W 13 St & 6 Ave
#
#    start station latitude  start station longitude  \
# 0               40.732264               -73.998522
# 1               40.693830               -73.990539
# 2               40.761227               -73.960940
# 3               40.713079               -73.998512
# 4               40.736494               -73.997044
#
#              end station name  end station latitude  end station longitude  \
# 0    Clinton Ave & Myrtle Ave             40.693261             -73.968896
# ...

# %%
citi_bike_df['trip duration'][3]
# Out:
# 437.0

# %%
citi_bike_df['weekend'] = citi_bike_df['starttime'].dt.dayofweek

# %%
citi_bike_df['weekend'] = citi_bike_df['weekend'].apply(lambda x: True if x > 4 else False)

# %%
citi_bike_df[citi_bike_df['weekend'] == True].shape[0]
# Out:
# 115135

# %%
def calc_time_of_day(input_hour):
    if 0 <= input_hour and input_hour <= 6:
        return 'night'
    if 6 < input_hour and input_hour <= 12:
        return 'morning'
    if 12 < input_hour and input_hour <= 18:
        return 'day'
    if 18 < input_hour and input_hour <= 23:
        return 'evening'

# %%
citi_bike_df['time_of_day'] = citi_bike_df['starttime'].dt.hour
citi_bike_df['time_of_day'].value_counts()
# Out:
# 17    29597
# 18    29103
# 16    23105
# 15    21110
# 14    20205
#       ...
# 1      1977
# 5      1592
# 2      1299
# 3       793
# 4       739
# Name: time_of_day, Length: 24, dtype: int64

# %%
citi_bike_df['time_of_day'] = citi_bike_df['time_of_day'].apply(calc_time_of_day)

# %%
citi_bike_df['time_of_day'].value_counts()
# Out:
# day        143014
# morning     95530
# evening     46375
# night       15081
# Name: time_of_day, dtype: int64

# %%
citi_bike_df[citi_bike_df['time_of_day'] == 'day'].shape[0] / citi_bike_df[citi_bike_df['time_of_day'] == 'night'].shape[0]
# Out:
# 9.483058152642398

# %%
citi_bike_df['time_of_day'].value_counts()
# Out:
# day        143014
# morning     95530
# evening     46375
# night       15081
# Name: time_of_day, dtype: int64

# %%
citi_bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  datetime64[ns]
#  1   stoptime                 300000 non-null  datetime64[ns]
#  2   start station name       299831 non-null  object
#  3   start station latitude   300000 non-null  float64
#  4   start station longitude  300000 non-null  float64
#  5   end station name         299831 non-null  object
#  6   end station latitude     300000 non-null  float64
#  7   end station longitude    300000 non-null  float64
#  8   bikeid                   300000 non-null  int64
#  9   usertype                 300000 non-null  object
#  10  age                      300000 non-null  int64
#  11  gender                   300000 non-null  int64
#  12  trip duration            300000 non-null  float64
# ...

# %%
citi_bike_df['time_of_day'] = citi_bike_df['time_of_day'].astype('category')

# %%
citi_bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  datetime64[ns]
#  1   stoptime                 300000 non-null  datetime64[ns]
#  2   start station name       299831 non-null  object
#  3   start station latitude   300000 non-null  float64
#  4   start station longitude  300000 non-null  float64
#  5   end station name         299831 non-null  object
#  6   end station latitude     300000 non-null  float64
#  7   end station longitude    300000 non-null  float64
#  8   bikeid                   300000 non-null  int64
#  9   usertype                 300000 non-null  object
#  10  age                      300000 non-null  int64
#  11  gender                   300000 non-null  int64
#  12  trip duration            300000 non-null  float64
# ...

# %%
citi_bike_df.head(5)
# Out:
#             starttime            stoptime               start station name  \
# 0 2018-09-01 00:00:05 2018-09-01 00:27:21     MacDougal St & Washington Sq
# 1 2018-09-01 00:00:11 2018-09-01 00:02:23  Cadman Plaza West & Montague St
# 2 2018-09-01 00:00:21 2018-09-01 00:55:59                  1 Ave & E 62 St
# 3 2018-09-01 00:00:22 2018-09-01 00:07:39          St James Pl & Oliver St
# 4 2018-09-01 00:00:27 2018-09-01 02:21:25                  W 13 St & 6 Ave
#
#    start station latitude  start station longitude  \
# 0               40.732264               -73.998522
# 1               40.693830               -73.990539
# 2               40.761227               -73.960940
# 3               40.713079               -73.998512
# 4               40.736494               -73.997044
#
#              end station name  end station latitude  end station longitude  \
# 0    Clinton Ave & Myrtle Ave             40.693261             -73.968896
# ...
