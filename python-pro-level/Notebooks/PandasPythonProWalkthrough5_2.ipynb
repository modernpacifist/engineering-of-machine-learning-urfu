# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/modernpacifist/engineering-of-machine-learning-urfu/master/python-pro-level/Datasets/melb_data_fe.csv', sep=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
#  16  Longtitude       13580 non-null  float64
#  17  Regionname       13580 non-null  object
#  18  Propertycount    13580 non-null  int64
#  19  MeanRoomsSquare  13580 non-null  float64
#  20  AreaRatio        13580 non-null  float64
#  21  MonthSale        13580 non-null  int64
#  22  AgeBuilding      13580 non-null  int64
#  23  WeekdaySale      13580 non-null  int64
#  24  StreetType       13580 non-null  object
#  25  Weekend          13580 non-null  int64
# dtypes: float64(8), int64(10), object(8)
# memory usage: 2.7+ MB

# %%
df.head(5)
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  Bathroom  Car  Landsize  BuildingArea CouncilArea  \
# 0      3067        2         1    1     202.0         126.0       Yarra
# 1      3067        2         1    0     156.0          79.0       Yarra
# 2      3067        3         2    0     134.0         150.0       Yarra
# 3      3067        3         2    1      94.0         126.0       Yarra
# 4      3067        3         1    2     120.0         142.0       Yarra
#
#    Lattitude  Longtitude             Regionname  Propertycount  \
# 0   -37.7996    144.9984  Northern Metropolitan           4019
# 1   -37.8079    144.9934  Northern Metropolitan           4019
# 2   -37.8093    144.9944  Northern Metropolitan           4019
# 3   -37.7969    144.9969  Northern Metropolitan           4019
# 4   -37.8072    144.9941  Northern Metropolitan           4019
#
#    MeanRoomsSquare  AreaRatio  MonthSale  AgeBuilding  WeekdaySale StreetType  \
# 0            25.20  -0.231707          3           46            5         St
# 1            15.80  -0.327660          4          116            5         St
# 2            18.75   0.056338          4          117            0         St
# 3            15.75   0.145455          4           47            0      other
# 4            17.75   0.083969          4            2            2         St
#
#    Weekend
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0

# %%
round(df[df['Weekend'] == 1]['Price'].mean())
# Out:
# 1083292

# %%
df[(df['SellerG'] == 'Nelson')]['Price'].min() / df[(df['SellerG'] == 'other')]['Price'].min()
# Out:
# 1.297709923664122

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
#  16  Longtitude       13580 non-null  float64
#  17  Regionname       13580 non-null  object
#  18  Propertycount    13580 non-null  int64
#  19  MeanRoomsSquare  13580 non-null  float64
#  20  AreaRatio        13580 non-null  float64
#  21  MonthSale        13580 non-null  int64
#  22  AgeBuilding      13580 non-null  int64
#  23  WeekdaySale      13580 non-null  int64
#  24  StreetType       13580 non-null  object
#  25  Weekend          13580 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(10), object(7)
# memory usage: 2.7+ MB

# %%
def get_year_quarter(month_num):
    if 12 <= month_num and month_num <= 2:
        return 1
    if 3 <= month_num and month_num <= 5:
        return 2
    if 6 <= month_num and month_num <= 8:
        return 3
    if 9 <= month_num and month_num <= 11:
        return 4
    return None

# %%
df['quarter'] = df['Date'].dt.quarter

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
#  16  Longtitude       13580 non-null  float64
#  17  Regionname       13580 non-null  object
#  18  Propertycount    13580 non-null  int64
#  19  MeanRoomsSquare  13580 non-null  float64
#  20  AreaRatio        13580 non-null  float64
#  21  MonthSale        13580 non-null  int64
#  22  AgeBuilding      13580 non-null  int64
#  23  WeekdaySale      13580 non-null  int64
#  24  StreetType       13580 non-null  object
#  25  Weekend          13580 non-null  int64
#  26  quarter          13580 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(11), object(7)
# memory usage: 2.8+ MB

# %%
df.head(1)
# Out:
#        Suburb  Rooms   Type      Price Method SellerG       Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin 2016-03-12       2.5
#
#    Postcode  Bedroom  Bathroom  Car  Landsize  BuildingArea CouncilArea  \
# 0      3067        2         1    1     202.0         126.0       Yarra
#
#    Lattitude  Longtitude             Regionname  Propertycount  \
# 0   -37.7996    144.9984  Northern Metropolitan           4019
#
#    MeanRoomsSquare  AreaRatio  MonthSale  AgeBuilding  WeekdaySale StreetType  \
# 0             25.2  -0.231707          3           46            5         St
#
#    Weekend  quarter
# 0        1        1

# %%
df['quarter'].value_counts()
# Out:
# 3    4873
# 2    4359
# 4    2329
# 1    2019
# Name: quarter, dtype: int64

# %%
cols_to_exclude = ["Date", "Rooms", "Bedroom", "Bathroom", "Car", "quarter"]
max_unique_count = 150
for col in df.columns:
    if df[col].nunique() < max_unique_count and col not in cols_to_exclude:
        df[col] = df[col].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
#  16  Longtitude       13580 non-null  float64
#  17  Regionname       13580 non-null  category
#  18  Propertycount    13580 non-null  int64
#  19  MeanRoomsSquare  13580 non-null  float64
#  20  AreaRatio        13580 non-null  float64
#  21  MonthSale        13580 non-null  category
#  22  AgeBuilding      13580 non-null  int64
#  23  WeekdaySale      13580 non-null  category
#  24  StreetType       13580 non-null  category
#  25  Weekend          13580 non-null  category
#  26  quarter          13580 non-null  int64
# dtypes: category(10), datetime64[ns](1), float64(8), int64(8)
# memory usage: 1.9 MB

# %%
df.sort_values(by='Price').head(10)
# Out:
#                Suburb  Rooms   Type     Price Method        SellerG  \
# 2652        Footscray      1   unit   85000.0     PI        Burnham
# 1805            other      4  house  131000.0     PI          other
# 7303           Albion      1   unit  145000.0     PI         Biggin
# 1927           Coburg      4  house  145000.0     PI         Jellis
# 7940         Hawthorn      1   unit  160000.0     VB            HAR
# 12666       Brunswick      1   unit  170000.0     VB         Nelson
# 8811        Footscray      1   unit  170000.0     PI        Burnham
# 8504   West Footscray      1   unit  185000.0     PI            Jas
# 7293           Albion      1   unit  185000.0      S  hockingstuart
# 7305           Albion      2   unit  190000.0     SP        Burnham
#
#             Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 2652  2016-03-09       6.4      3011        1         1    0       0.0
# 1805  2017-02-25       8.9      3162        4         1    2     499.0
# 7303  2016-05-28      13.9      3020        2         1    1      36.0
# 1927  2016-04-06       7.8      3058        3         1    1     536.0
# 7940  2017-08-04       4.6      3122        1         1    0     322.0
# 12666 2017-09-16       5.2      3056        1         1    0    1250.0
# 8811  2017-01-07       5.1      3011        1         1    0      30.0
# 8504  2017-04-29       8.2      3012        1         1    1       0.0
# 7293  2016-08-22      13.9      3020        1         1    1    2347.0
# 7305  2016-07-30      13.9      3020        2         1    1       0.0
#
#        BuildingArea  CouncilArea  Lattitude  Longtitude  \
# 2652          126.0  Maribyrnong  -37.79110   144.89000
# 1805          155.0    Glen Eira  -37.88640   145.02420
# 7303          126.0     Brimbank  -37.78330   144.82660
# 1927          164.0     Moreland  -37.75550   144.96580
# 7940          126.0   Boroondara  -37.81980   145.03730
# 12666         126.0          NaN  -37.77685   144.95188
# 8811           26.0  Maribyrnong  -37.80141   144.89587
# 8504          126.0  Maribyrnong  -37.79800   144.86720
# 7293           43.0     Brimbank  -37.78520   144.82720
# 7305          126.0     Brimbank  -37.78390   144.82390
#
#                   Regionname  Propertycount  MeanRoomsSquare  AreaRatio  \
# 2652    Western Metropolitan           7570        42.000000   1.000000
# 1805   Southern Metropolitan           2379        17.222222  -0.525994
# 7303    Western Metropolitan           2185        31.500000   0.555556
# 1927   Northern Metropolitan          11204        20.500000  -0.531429
# 7940   Southern Metropolitan          11308        42.000000  -0.437500
# 12666  Northern Metropolitan          11918        42.000000  -0.816860
# 8811    Western Metropolitan           7570         8.666667  -0.071429
# 8504    Western Metropolitan           5058        42.000000   1.000000
# 7293    Western Metropolitan           2185        14.333333  -0.964017
# 7305    Western Metropolitan           2185        25.200000   1.000000
#
#       MonthSale  AgeBuilding WeekdaySale StreetType Weekend  quarter
# 2652          3            9           2         St       0        1
# 1805          2           97           5         St       1        1
# 7303          5           46           5         St       1        2
# 1927          4          106           2         Rd       0        2
# 7940          8            8           4         St       0        3
# 12666         9           47           5         St       1        3
# 8811          1            4           5         St       1        1
# 8504          4           47           5         St       1        2
# 7293          8           41           0         Rd       0        3
# 7305          7           46           5         St       1        3

# %%
df.sort_values(by='Date', ascending=False).head(10)
# Out:
#               Suburb  Rooms   Type      Price Method        SellerG  \
# 11144      Northcote      4  house  1955000.0     SP        McGrath
# 11217   Surrey Hills      3  house  1775000.0     PI         Jellis
# 11206       St Kilda      4  house  1600000.0     VB           Gary
# 11207     Strathmore      7  house  2000000.0     SP         Nelson
# 11208     Strathmore      4  house  1610000.0      S          other
# 11209     Strathmore      3  house  1742000.0      S          Barry
# 11210     Strathmore      3  house  1016000.0      S          other
# 11211       Sunshine      3  house   700000.0     SP          other
# 11212       Sunshine      2  house   615000.0     SP          Barry
# 11213  Sunshine West      3  house   650000.0     VB  hockingstuart
#
#             Date  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 11144 2017-12-08       5.3      3070        4         2    1       5.0
# 11217 2017-12-08      10.2      3127        3         2    2     780.0
# 11206 2017-12-08       5.0      3182        4         2    3     613.0
# 11207 2017-12-08       8.2      3041        7         3    4     608.0
# 11208 2017-12-08       8.2      3041        4         3    2     861.0
# 11209 2017-12-08       8.2      3041        3         2    3     697.0
# 11210 2017-12-08       8.2      3041        3         2    1     304.0
# 11211 2017-12-08      10.5      3020        3         2    1     485.0
# 11212 2017-12-08      10.5      3020        2         1    0     418.0
# 11213 2017-12-08      10.5      3020        3         1    2     691.0
#
#        BuildingArea    CouncilArea  Lattitude  Longtitude  \
# 11144         126.0        Darebin  -37.76280   144.99375
# 11217         126.0     Boroondara  -37.81403   145.08968
# 11206         160.0   Port Phillip  -37.86667   144.98324
# 11207         355.0  Moonee Valley  -37.73681   144.90587
# 11208         274.0  Moonee Valley  -37.73154   144.92243
# 11209         126.0  Moonee Valley  -37.74057   144.92172
# 11210         126.0  Moonee Valley  -37.73456   144.91521
# 11211         130.0       Brimbank  -37.78703   144.84569
# 11212          94.0       Brimbank  -37.79595   144.83206
# 11213         126.0       Brimbank  -37.78825   144.80099
#
#                   Regionname  Propertycount  MeanRoomsSquare  AreaRatio  \
# 11144  Northern Metropolitan          11364        12.600000   0.923664
# 11217  Southern Metropolitan           5457        15.750000  -0.721854
# 11206  Southern Metropolitan          13240        16.000000  -0.586028
# 11207   Western Metropolitan           3284        20.882353  -0.262721
# 11208   Western Metropolitan           3284        24.909091  -0.517181
# 11209   Western Metropolitan           3284        15.750000  -0.693803
# 11210   Western Metropolitan           3284        15.750000  -0.413953
# 11211   Western Metropolitan           3755        16.250000  -0.577236
# 11212   Western Metropolitan           3755        18.800000  -0.632812
# 11213   Western Metropolitan           6763        18.000000  -0.691554
#
#       MonthSale  AgeBuilding WeekdaySale StreetType Weekend  quarter
# 11144        12           47           4         St       0        4
# 11217        12           47           4         Rd       0        4
# 11206        12          107           4         St       0        4
# 11207        12           18           4         Rd       0        4
# 11208        12           62           4         St       0        4
# 11209        12           47           4         Rd       0        4
# 11210        12           47           4         St       0        4
# 11211        12           67           4         St       0        4
# 11212        12           77           4         St       0        4
# 11213        12           47           4         St       0        4

# %%
df.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']].head(10)
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# 9511        1.3  1350000.0
# 6866        1.5   872000.0
# 2102        1.6   366000.0
# 2103        1.6   461000.0
# 2545        1.6   660000.0

# %%
df.sort_values(by=['Price', 'Distance']).loc[::10, ['Price', 'Distance']].head(10)
# Out:
#           Price  Distance
# 2652    85000.0       6.4
# 7116   200000.0       7.8
# 5206   220000.0      11.2
# 7240   241000.0       8.2
# 2898   250000.0      13.0
# 5056   260000.0      11.2
# 4116   265000.0       6.9
# 10024  270000.0      12.0
# 6272   277500.0       6.5
# 11559  280000.0       7.5
