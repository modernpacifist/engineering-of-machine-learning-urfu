# %% [markdown]
# #  Импорт

# %%
import numpy as np # библиотека Numpy для операций линейной алгебры и прочего
import pandas as pd # Библиотека Pandas для работы с табличными данными
import matplotlib.pyplot as plt # библиотека Matplotlib для визуализации
from matplotlib.colors import ListedColormap # функция библиотеки Matplotlib, которая генерирует цветовую карту

import seaborn as sns# библиотека Seaborn для визуализации данных из Pandas

from sklearn.datasets import make_moons, make_circles, make_classification # генерируемые наборы данных

# %% [markdown]
# # Данные
#
# Наши старые друзья / знакомые

# %%
def plot_data(ax,ds,name='',marker = 'o',colors =("#FF0000", '#0000FF'),alpha=0.7, s = 150, facecolor=True):
    """Визуализация двумерных  данных для классификации
    Входные переменные:
    ===========
    ax: отдельная ячейка объекта figure
    ds: набор данных, содержащий признаки X и целевые метки y
    name: название графика
    marker: тип маркера - по умолчанию просто круги
    colors: цвета, которые будут использоваться для раскраски разных классов - по умолчанию Красный и Синий
    alpha: прозрачность маркеров
    s: размер маркера (~ квадрат радиуса)
    facecolor:
    """

    X, y = ds # распаковываем признаки и целевые метки в отдельные переменные

    cm_bright = ListedColormap(colors) # формируем цветовую карту из наших цветов
    ax.set_title(name, fontsize = 30) # прописываем название графика
    if facecolor: # если переменная задана, то просто рисуем скатерограмму по признакам с использованием параметров маркеров
        ax.scatter(X[:, 0], X[:, 1],
                   marker = marker, c=y,
                   cmap=cm_bright,s = s,
                   alpha =alpha)
    else: # иначе так же рисуем скатерограмму, но без
        ax.scatter(X[:, 0], X[:, 1],
                   marker = marker, c=y,
                   cmap=cm_bright,s = s,
                   facecolor = 'None',
                   alpha =alpha)
    # немного красоты и аккуратности
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5 # фиксируем минимальные и максимальные значения по горизонтали
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5 # фиксируем минимальные и максимальные значения по вертикали
    ax.grid(True)
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)
    ax.set_xticks(())
    ax.set_yticks(())

# %%
def make_binary_clf(N, method = 'line',
                    noises = 0.15,
                    random_state = 42,):
    """Создание синтетического набора данных
    для бинарной классификации
    Входные переменные:
    ===========
    N: количество точек
    method: тип набора данных
    noises: коэффициент ~ сила шума
    random_state: фиксированный сид случайных чисел (для повторяемости)
    """
    # фиксируем случайный seed
    if random_state: rng = np.random.RandomState(seed = random_state)

    if method == 'line' or method is None:
        # если выбран метод line (или никакой не задан)
        # то мы создаем набор данных с использованием функции make_classification
        # это будут линейно-разделимые данные
        X, y = make_classification(n_samples=N, # количество точек
                                   n_features=2, # количество признаков
                                   n_redundant=0, # количество бесполезных признаков
                                   n_informative=2,# количество информативных признаков
                                   n_clusters_per_class=1, # количество групп точек на класс
                                   class_sep=2, # количество классов
                                   random_state=random_state # фиксированный сид случайных чисел
                                   )
        X += np.random.randn(*X.shape) *noises # добавляем к признакам случайный шум

    elif method == 'moons':
        # если выбран метод moons
        # то мы создаем набор данных с использованием функции make_moons
        # это будут данные похожие на Инь-Ян
        X, y = make_moons(n_samples=N, # количество точек
                          noise=noises, # уровень шума
                          random_state=random_state # фиксированный сид случайных чисел
                          )

    elif method == 'circles':
        # если выбран метод circles
        # то мы создаем набор данных с использованием функции make_circles
        # это будут данные в виде концентрических окружностей
        X, y = make_circles(n_samples=N, # количество точек
                            noise=noises, # уровень шума
                            factor=0.5, # соотношение радиусов внуренней и внешней окружности
                            random_state=random_state # фиксированный сид случайных чисел
                            )


    return X,y

# %%
#@title визуализация данных { run: "auto" }
N = 150 #@param {type:"slider", min:50, max:250, step:25}
noises = 0.15 #@param {type:"slider", min:0, max:1, step:0.05}

fig=plt.figure(figsize=(30,8))

ax = plt.subplot(1, 3, 1)
plot_data(ax,make_binary_clf(N,method = 'line',
                             noises = noises),
          'Линейно разделимые')
ax = plt.subplot(1, 3, 2)
plot_data(ax,make_binary_clf(N,method = 'moons',
                             noises = noises),
          'Инь-Ян (Moons)')
ax = plt.subplot(1, 3, 3)
plot_data(ax, make_binary_clf(N,method = 'circles',
                              noises = noises),
          'Круги')

# %% [markdown]
# За неимением лучшего аналога тестировать алгоритмы кластеризации будем на тех же наборах, что и классификацию

# %% [markdown]
# # Спектральная кластеризация

# %% [markdown]
# Начнем по традиции с простых данных - линейно разделимых
#
# тут мы сгенерировали меньше точек чтобы проще работать с матрицей смежности

# %%
N = 25
X,y = make_binary_clf(N,method = 'line', noises=0.05, )
ax = plt.subplot(1, 1, 1)
plot_data(ax,(X,y))

# %%
from sklearn.cluster import SpectralClustering # Спектральная Кластеризация от Scikit-learn

# %% [markdown]
# По традиции мы сначала создаем объект нужного нам класса, в котором мы можем изменять гиперпараметры
#
# В случае Спектральной рекомендуется варьировать
#
# *   количество кластеров `n_clusters`
# *   подход к вычислению матрицы смежности `affinity`
#  * `'nearest_neighbors'`: Граф К Ближайших Соседей
#         * `'n_neighbors'`: количество К соседей
#
#  * `'rbf'`: Радиальная базисная функция
#      * `'gamma'`: параметр радиальной функции

# %%
# Создаем Класс Спектральной Кластеризации
sc = SpectralClustering(n_clusters=2,
                     affinity = 'rbf',
                     gamma = 1
                     )

sc
# Out:
# SpectralClustering(gamma=1, n_clusters=2)

# %% [markdown]
# Традиционно обучаем методом `.fit()`

# %%
sc.fit(X);

# %% [markdown]
# **Важно**
#
# Предсказание меток кластеров - с помощью метода `.fit_predict()`
#
# Т.е. нельзя предсказывать на новых данных

# %%
labels = sc.fit_predict(X)

# %% [markdown]
# Запишем функцию для визуализации результатов кластеризации

# %%
def plot_clustering(X, sc):
    """Результатов кластеризации
    Входные переменные:
    ===========
    X: данные на которых мы хотим построить визуализацию
    sc: обученный класс Спектральной кластеризации
    """
    labels = sc.fit_predict(X) # предсказываем метки кластеров
    ax = plt.subplot(1, 1, 1) # создаем полотно
    # отрисовываем скатерограмму
    ax.scatter(X[:, 0], X[:, 1], # данные
                    c=labels,  # подкрашиваем по предсказанным меткам
                    alpha = 0.75, # прозрачность
                    cmap = 'bwr', # тип цветовой карты
                    edgecolor = 'k', # цвет края - черный
                    s = 100  # размер
               )
    plt.xticks([],[])
    plt.yticks([],[])

# %%
plot_clustering(X, sc)

# %% [markdown]
# ## Анализ матрицы смежности

#         1.36622140e-08, 1.96353479e-02, 2.73337216e-04, 7.57001855e-01,
#         2.15168264e-05, 1.93268014e-04, 1.00000000e+00, 5.48380679e-01,
#         3.34619242e-04],
#        [5.34624588e-01, 2.75910122e-03, 9.46403957e-03, 5.21863104e-02,
#         2.29330211e-03, 1.98974860e-09, 1.94974436e-01, 4.54425607e-04,
#         5.46706738e-04, 7.99097041e-09, 8.21595516e-07, 7.24050746e-01,
#         1.29823164e-02, 4.38099267e-01, 7.58594046e-04, 8.06551851e-04,
#         5.32177258e-07, 1.11974462e-03, 1.26666118e-02, 5.73546325e-01,
#         9.15748898e-04, 8.04241063e-03, 5.48380679e-01, 1.00000000e+00,
#         1.46569170e-02],
#        [3.56226163e-02, 3.04196465e-01, 9.08810342e-01, 1.78814874e-05,
#         1.52865389e-01, 1.27634323e-07, 9.18209905e-05, 4.11709893e-02,
#         4.72717130e-02, 6.54177218e-07, 4.83129534e-05, 3.48563322e-02,
#         1.38121518e-07, 2.27349135e-03, 1.89931799e-07, 2.71837044e-08,
#         6.10939964e-05, 1.19830621e-09, 9.98361726e-01, 7.23267159e-04,
#         8.77780004e-02, 5.82759864e-01, 3.34619242e-04, 1.46569170e-02,
#         1.00000000e+00]])

# %%
def viz_df(data, vmin = 0, vmax = 1):
    """Визуализация данных в виде подкрашиваемой таблички
    Входные переменные:
    ===========
    data: данные
    vmin: указываем нижний диапазон
    vmax: указываем верхний  диапазон
    """
    cm = sns.color_palette("vlag", as_cmap=True)    # создадим цветовой стиль, чтобы раскрасить табличку

    DF = pd.DataFrame(data).style.background_gradient(cmap=cm,    # наш цветовой стиль
                                        vmin = vmin,  # указываем нижний диапазон
                                        vmax = vmax # указываем верхний  диапазон
                                        ).format(precision=3) # округление чисел

    display(DF)

# %% [markdown]
# Для удобвства воспользуемся функцией

# %%
viz_df(sc.affinity_matrix_)
# Out:
# <style type="text/css">
# #T_1d1b0_row0_col0, #T_1d1b0_row1_col1, #T_1d1b0_row2_col2, #T_1d1b0_row3_col3, #T_1d1b0_row4_col4, #T_1d1b0_row5_col5, #T_1d1b0_row6_col6, #T_1d1b0_row7_col7, #T_1d1b0_row7_col8, #T_1d1b0_row8_col7, #T_1d1b0_row8_col8, #T_1d1b0_row9_col9, #T_1d1b0_row10_col10, #T_1d1b0_row11_col11, #T_1d1b0_row12_col12, #T_1d1b0_row13_col13, #T_1d1b0_row14_col14, #T_1d1b0_row15_col15, #T_1d1b0_row16_col16, #T_1d1b0_row17_col17, #T_1d1b0_row18_col18, #T_1d1b0_row18_col24, #T_1d1b0_row19_col19, #T_1d1b0_row20_col20, #T_1d1b0_row21_col21, #T_1d1b0_row22_col22, #T_1d1b0_row23_col23, #T_1d1b0_row24_col18, #T_1d1b0_row24_col24 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
_col19, #T_1d1b0_row7_col22, #T_1d1b0_row7_col23, #T_1d1b0_row8_col0, #T_1d1b0_row8_col3, #T_1d1b0_row8_col6, #T_1d1b0_row8_col11, #T_1d1b0_row8_col12, #T_1d1b0_row8_col13, #T_1d1b0_row8_col14, #T_1d1b0_row8_col15, #T_1d1b0_row8_col17, #T_1d1b0_row8_col19, #T_1d1b0_row8_col22, #T_1d1b0_row8_col23, #T_1d1b0_row9_col0, #T_1d1b0_row9_col1, #T_1d1b0_row9_col2, #T_1d1b0_row9_col3, #T_1d1b0_row9_col4, #T_1d1b0_row9_col6, #T_1d1b0_row9_col11, #T_1d1b0_row9_col12, #T_1d1b0_row9_col13, #T_1d1b0_row9_col14, #T_1d1b0_row9_col15, #T_1d1b0_row9_col17, #T_1d1b0_row9_col18, #T_1d1b0_row9_col19, #T_1d1b0_row9_col21, #T_1d1b0_row9_col22, #T_1d1b0_row9_col23, #T_1d1b0_row9_col24, #T_1d1b0_row10_col0, #T_1d1b0_row10_col2, #T_1d1b0_row10_col3, #T_1d1b0_row10_col6, #T_1d1b0_row10_col11, #T_1d1b0_row10_col12, #T_1d1b0_row10_col13, #T_1d1b0_row10_col14, #T_1d1b0_row10_col15, #T_1d1b0_row10_col17, #T_1d1b0_row10_col18, #T_1d1b0_row10_col19, #T_1d1b0_row10_col21, #T_1d1b0_row10_col22, #T_1d1b0_row10_col23, #T_1d1b0_row10_col24, #T_1d1b0_row11_col1, #T_1d1b0_row11_col4, #T_1d1b0_row11_col5, #T_1d1b0_row11_col7, #T_1d1b0_row11_col8, #T_1d1b0_row11_col9, #T_1d1b0_row11_col10, #T_1d1b0_row11_col14, #T_1d1b0_row11_col15, #T_1d1b0_row11_col16, #T_1d1b0_row11_col17, #T_1d1b0_row11_col20, #T_1d1b0_row12_col1, #T_1d1b0_row12_col2, #T_1d1b0_row12_col4, #T_1d1b0_row12_col5, #T_1d1b0_row12_col7, #T_1d1b0_row12_col8, #T_1d1b0_row12_col9, #T_1d1b0_row12_col10, #T_1d1b0_row12_col16, #T_1d1b0_row12_col18, #T_1d1b0_row12_col20, #T_1d1b0_row12_col21, #T_1d1b0_row12_col24, #T_1d1b0_row13_col1, #T_1d1b0_row13_col2, #T_1d1b0_row13_col4, #T_1d1b0_row13_col5, #T_1d1b0_row13_col7, #T_1d1b0_row13_col8, #T_1d1b0_row13_col9, #T_1d1b0_row13_col10, #T_1d1b0_row13_col16, #T_1d1b0_row13_col18, #T_1d1b0_row13_col20, #T_1d1b0_row1 ...

# %%
from scipy.sparse import csgraph # Модуль для быстрой обработки графов, основанные на представлении разреженных матриц
from numpy import linalg as LA #Модуль Линейной алгебры

def get_eigen_am(sc):
    """Оценка собственных значений и собственных векторов для матрицы смежности
    Входные переменные:
    ===========
    sc: обученный класс Спектральной кластеризации
    """
    # Построение матрицы Лапласиана
    L = csgraph.laplacian(sc.affinity_matrix_, normed = True)

    # Вычисление собственных значений и векторов
    try:
        eigenvalues, eigenvectors = LA.eigh(L.todense())
    except:
        eigenvalues, eigenvectors = LA.eigh(L)

    # Сортировка по возрастанию собственных значений
    sorted_indexes = np.argsort(eigenvalues)
    eigenvalues = eigenvalues[sorted_indexes]
    eigenvectors = np.array(eigenvectors[:,sorted_indexes])

    return eigenvalues, eigenvectors

# %% [markdown]
# Оценим собственные вектора и собственные значения для лапласиана наших данных

# %%
eigenvalues, eigenvectors = get_eigen_am(sc)

# %%
viz_df(eigenvectors, vmin = -0.7, vmax = 0.7)
# Out:
# <style type="text/css">
# #T_786ea_row0_col0, #T_786ea_row2_col2, #T_786ea_row18_col0, #T_786ea_row21_col2, #T_786ea_row23_col0 {
#   background-color: #c8cfdd;
#   color: #000000;
# }
# #T_786ea_row0_col1 {
#   background-color: #c2cada;
#   color: #000000;
# }
# #T_786ea_row0_col2, #T_786ea_row0_col4, #T_786ea_row0_col8, #T_786ea_row0_col9, #T_786ea_row0_col13, #T_786ea_row0_col15, #T_786ea_row0_col16, #T_786ea_row0_col20, #T_786ea_row0_col21, #T_786ea_row0_col22, #T_786ea_row0_col23, #T_786ea_row0_col24, #T_786ea_row1_col5, #T_786ea_row1_col7, #T_786ea_row1_col10, #T_786ea_row1_col20, #T_786ea_row1_col21, #T_786ea_row1_col22, #T_786ea_row1_col23, #T_786ea_row2_col3, #T_786ea_row2_col5, #T_786ea_row2_col7, #T_786ea_row2_col10, #T_786ea_row2_col15, #T_786ea_row2_col19, #T_786ea_row2_col22, #T_786ea_row3_col11, #T_786ea_row3_col12, #T_786ea_row3_col20, #T_786ea_row3_col21, #T_786ea_row4_col6, #T_786ea_row4_col7, #T_786ea_row4_col14, #T_786ea_row4_col20, #T_786ea_row4_col21, #T_786ea_row4_col23, #T_786ea_row4_col24, #T_786ea_row5_col3, #T_786ea_row5_col5, #T_786ea_row5_col7, #T_786ea_row5_col10, #T_786ea_row5_col14, #T_786ea_row5_col15, #T_786ea_row5_col17, #T_786ea_row5_col18, #T_786ea_row5_col19, #T_786ea_row5_col21, #T_786ea_row5_col24, #T_786ea_row6_col13, #T_786ea_row6_col15, #T_786ea_row6_col20, #T_786ea_row6_col21, #T_786ea_row7_col10, #T_786ea_row7_col14, #T_786ea_row7_col17, #T_786ea_row7_col18, #T_786ea_row7_col19, #T_786ea_row8_col10, #T_786ea_row8_col17, #T_786ea_row8_col18, #T_786ea_row8_col19, #T_786ea_row9_col3, #T_786ea_row9_col5, #T_786ea_row9_col7, #T_786ea_row9_col10, #T_786ea_row9_col14, #T_786ea_row9_col15, #T_786ea_row9_col17, #T_786ea_row9_col18, #T_786ea_row9_col19, #T_786ea_row9_col22, #T_786ea_row10_col3, #T_786ea_row10_col6, #T_786ea_row10_col16, #T_786ea_row10_col20, #T_786ea_row10_col22, #T_786ea_row10_col24, #T_786ea_row11_col2, #T_786ea_row11_col4, #T_786ea_row11_col8, #T_786ea_row11_col9, #T_786ea_row11_col11, #T_786ea_row11_col13, #T_786ea_row11_col15, #T_786ea_row11_col20, #T_786ea
#   background-color: #faf5f5;
#   color: #000000;
# }
# #T_786ea_row0_col14, #T_786ea_row19_col6 {
#   background-color: #a2b2cd;
#   color: #000000;
# }
# #T_786ea_row0_col17, #T_786ea_row2_col1, #T_786ea_row10_col1, #T_786ea_row16_col1 {
#   background-color: #e8cac8;
#   color: #000000;
# }
# #T_786ea_row0_col18 {
#   background-color: #daa9a7;
#   color: #000000;
# }
# #T_786ea_row0_col19 {
#   background-color: #b55252;
#   color: #f1f1f1;
# }
# #T_786ea_row1_col1, #T_786ea_row4_col1, #T_786ea_row20_col1, #T_786ea_row22_col17 {
#   background-color: #e4c0be;
#   color: #000000;
# }
# #T_786ea_row1_col2, #T_786ea_row10_col0, #T_786ea_row16_col0, #T_786ea_row18_col2, #T_786ea_row22_col0, #T_786ea_row24_col2 {
#   background-color: #cdd3df;
#   color: #000000;
# }
# #T_786ea_row1_col3, #T_786ea_row2_col6, #T_786ea_row2_col8, #T_786ea_ro

# %% [markdown]
# ## Пространство собственных векторов

# %%
fig, ax = plt.subplots(1, 1, figsize = (5,5))

ax.scatter(eigenvectors[:,1],
           eigenvectors[:,2],
           cmap = 'bwr',
           c=labels,
           s = 75);

# %%
eigenvalues
# Out:
# array([1.97313451e-16, 1.16838547e-02, 1.14790827e-01, 3.21322990e-01,
#        4.97095123e-01, 6.94450978e-01, 8.69734513e-01, 9.60767046e-01,
#        1.04122641e+00, 1.10002627e+00, 1.18029495e+00, 1.19835736e+00,
#        1.19937462e+00, 1.21321218e+00, 1.22770140e+00, 1.23164836e+00,
#        1.24983772e+00, 1.25634378e+00, 1.25839412e+00, 1.29921926e+00,
#        1.31400957e+00, 1.37969254e+00, 1.44388050e+00, 1.45596758e+00,
#        1.48096803e+00])

# %%
#@title Применение Спектральной Кластеризации  { run: "auto" }
#@markdown ### потенциальное число кластеров
n_clusters = 2 #@param {type:"slider", min:2, max:10, step:1}
#@markdown ### подход к вычислению матрицы смежности
affinity = 'nearest_neighbors' #@param ["nearest_neighbors", "rbf"]{type:"string"}
#@markdown ### параметр радиальной функции
gamma = 1 #@param {type:"slider", min:-2, max:2, step:0.25}
#@markdown ### количество К соседей
n_neighbors = 13 #@param {type:"slider", min:1, max:25, step:4}

gamma = 10** gamma

# Создаем Класс Спектральной Кластеризации
sc = SpectralClustering(n_clusters=n_clusters,
                        affinity=affinity,
                        gamma= gamma,
                        n_neighbors = n_neighbors)

plot_clustering(X, sc)

# %% [markdown]
# Матрица смежности для Графа К Ближайших соседей
#
# чтобы визуализировать применяем метод `.todense()`

# %%
viz_df(sc.affinity_matrix_.todense())
# Out:
# <style type="text/css">
T_b5303_row4_col17, #T_b5303_row4_col19, #T_b5303_row4_col22, #T_b5303_row5_col0, #T_b5303_row5_col3, #T_b5303_row5_col6, #T_b5303_row5_col11, #T_b5303_row5_col12, #T_b5303_row5_col13, #T_b5303_row5_col14, #T_b5303_row5_col15, #T_b5303_row5_col17, #T_b5303_row5_col19, #T_b5303_row5_col22, #T_b5303_row5_col23, #T_b5303_row6_col1, #T_b5303_row6_col2, #T_b5303_row6_col4, #T_b5303_row6_col5, #T_b5303_row6_col7, #T_b5303_row6_col8, #T_b5303_row6_col9, #T_b5303_row6_col10, #T_b5303_row6_col16, #T_b5303_row6_col18, #T_b5303_row6_col20, #T_b5303_row6_col21, #T_b5303_row7_col0, #T_b5303_row7_col3, #T_b5303_row7_col6, #T_b5303_row7_col11, #T_b5303_row7_col12, #T_b5303_row7_col13, #T_b5303_row7_col14, #T_b5303_row7_col15, #T_b5303_row7_col17, #T_b5303_row7_col19, #T_b5303_row7_col22, #T_b5303_row7_col23, #T_b5303_row8_col0, #T_b5303_row8_col3, #T_b5303_row8_col6, #T_b5303_row8_col11, #T_b5303_row8_col12, #T_b5303

# %%
eigenvalues, eigenvectors = get_eigen_am(sc)

# %%
viz_df(eigenvectors, vmin = -0.7, vmax = 0.7)
# Out:
# <style type="text/css">
# #T_0d83c_row0_col0, #T_0d83c_row2_col0, #T_0d83c_row4_col1, #T_0d83c_row5_col1, #T_0d83c_row13_col0, #T_0d83c_row18_col0, #T_0d83c_row21_col0, #T_0d83c_row24_col22 {
#   background-color: #e3bfbd;
#   color: #000000;
# }
# #T_0d83c_row0_col1, #T_0d83c_row16_col21 {
#   background-color: #d7dae4;
#   color: #000000;
# }
# #T_0d83c_row0_col2 {
#   background-color: #adbbd1;
#   color: #000000;
# }
# #T_0d83c_row0_col3 {
#   background-color: #cb8481;
#   color: #f1f1f1;
# }
# #T_0d83c_row0_col4, #T_0d83c_row2_col1, #T_0d83c_row7_col4, #T_0d83c_row8_col4, #T_0d83c_row18_col1, #T_0d83c_row20_col4 {
#   background-color: #edd5d3;
#   color: #000000;
# }
# #T_0d83c_row0_col5, #T_0d83c_row1_col12, #T_0d83c_row9_col8, #T_0d83c_row10_col5, #T_0d83c_row10_col8 {
#   background-color: #f5e7e5;
#   color: #000000;
# }
# #T_0d83c_row0_col6 {
#   background-color: #d9a5a2;
#   color: #000000;
# }
# #T_0d83c_row0_col7, #T_0d83c_row0_col10, #T_0d83c_row0_col14, #T_0d83c_row0_col18, #T_0d83c_row1_col7, #T_0d83c_row1_col8, #T_0d83c_row1_col10, #T_0d83c_row1_col14, #T_0d83c_row1_col15, #T_0d83c_row1_col17, #T_0d83c_row2_col10, #T_0d83c_row2_col12, #T_0d83c_row2_col16, #T_0d83c_row2_col17, #T_0d83c_row2_col19, #T_0d83c_row3_col7, #T_0d83c_row3_col10, #T_0d83c_row3_col19, #T_0d83c_row4_col7, #T_0d83c_row4_col8, #T_0d83c_row4_col9, #T_0d83c_row4_col10, #T_
# #T_0d83c_row0_col23, #T_0d83c_row2_col6, #T_0d83c_row5_col6, #T_0d83c_row7_col20, #T_0d83c_row8_col20, #T_0d83c_row18_col6, #T_0d83c_row20_col20, #T_0d83c_row23_col6 {
#   background-color: #dcdee6;
#   color: #000000;
# }
# #T_0d83c_row0_col24 {
#   background-color: #d29491;
#   color: #f1f1f1;
# }
# #T_0d83c_row1_col0, #T_0d83c_row4_col0, #T_0d83c_row7_col0, #T_0d83c_row8_col0, #T_0d83c_row16_col2, #T_0d83c_row20_col0 {
#   background-color: #e5c2c0;
#   color: #000000;
# }
# #T_0d83c_row1_col1, #T_0d83c_row3_col0, #T_0d83c_row6_col0, #T_0d83c_row12_col0, #T_0d83c_row19_col0, #T_0d83c_row22_col0 {
#   background-color: #e5c3c1;
#   color: #000000;
# }
# #T_0d83c_row1_col2, #T_0d83c_row3_col22, #T_0d83c_row6_col22, #T_0d83c_row7_col21, #T_0d83c_row8_col21, #T_0d83c_row12_col22, #T_0d83c_row19_col22, #T_0d83c_row20_col21, #T_0d83c_row22_col22 {
#   background-color: #ebeaee;
#   color: #000000;
# }
# #T_0d83c_row1_col3, #T_0d83c_row11_col5, #T_0d83c_row16_col13 {
#   background-color: #8da4c6;
#   color: #f1f1f1;
# }
# #T_0d83c_row1_col4, #T_0d83c_row4_col3 {
#   background-color: #a3b4cd;
#   color: #000000;
# }
# #T_0d83c_row1_col5 {
#   background-color: #a8b7cf;
#   color: #000000;
# }
# #T_0d83c_row1_col6 {
#   background-color: #a2b2cd;
#   color: #000000;
# }
# #T_0d83c_row1_col11, #T_0d83c_row9_col13, #T_0d83c_row11_col0, #T_0d83c_row23_col23 {
#   background-color: #e3bdbb;
#   color: #000000;
# }
# #T_0d83c_row1_col13, #T_0d83c_row5_col21, #T_0d83c_row14_col8, #T_0d83c_row15_col8, #T_0d83c_row17_col8 {
#   background-color: #c2cada;
#   color: #000000;
# }
# #T_0d83c_row1_col21 {
#   background-color: #ce8b88;
#   color: #f1f1f1;
# }
# #T_0d83c_row1_col22, #T_0d83c_row23_col20 {
#   background-color: #f2e0df;
#   color: #000000;
# }
# #T_0d83c_row1_col23 {
#   background-color: #8ba3c6;
#   color: #f1f1f1;
# }
# #T_0d83c_row1_col24, #T_0d83c_row13_col24 {
#   background-color: #faf4f3;
#   color: #000000;
# }
# #T_0d83c_row2_col2, #T_0d83c_row16_col4, #T_0d83c_row18_col2 {
#   background-color: #a5b5ce;
#   color: #000000;
# }
# #T_0d83c_row2_col3, #T_0d83c_row3_col23, #T_0d83c_row5_col24, #T

# %% [markdown]
# # Задание
#
# Проверить алгоритм Спектральной Кластеризации на данных Инь-Ян  и Круги

# %%
N = 25
X_circle,y_circle = make_binary_clf(N,method = 'circles', noises=0.05, )
ax = plt.subplot(1, 1, 1)
plot_data(ax,(X_circle,y_circle))

# %%
N = 25
X_moons,y_moons = make_binary_clf(N,method = 'moons', noises=0.05, )
ax = plt.subplot(1, 1, 1)
plot_data(ax,(X_moons,y_moons))
