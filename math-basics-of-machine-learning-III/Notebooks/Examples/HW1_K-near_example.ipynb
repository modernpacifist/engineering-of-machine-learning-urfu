# %% [markdown]
# # Цель Блокнота

# %% [markdown]
# Решение задачи регрессии в scikit-learn с помощью метрической модели - к-Ближайшие соседи
# * Обучение класса `KNeighborsRegressor`
# * Поиск лучших гиперпараметров модели с помощью классов `RandomizedSearchCV` и `GridSearchCV`
# * Сохранение модели

# %% [markdown]
# # Import библиотек

# %%
import pandas as pd # Библиотека Pandas для работы с табличными данными
import numpy as np # библиотека Numpy для операций линейной алгебры и прочего
import matplotlib.pyplot as plt # библиотека Matplotlib для визуализации
import seaborn as sns # библиотека seaborn для визуализации
import numpy as np # библиотека Numpy для операций линейной алгебры и прочего


# предварительная обработка числовых признаков
from sklearn.preprocessing import MinMaxScaler# Импортируем нормализацию от scikit-learn
from sklearn.preprocessing import StandardScaler # Импортируем стандартизацию от scikit-learn
from sklearn.preprocessing import PowerTransformer  # Степенное преобразование от scikit-learn
# предварительная обработка категориальных признаков
from sklearn.preprocessing import OneHotEncoder# Импортируем One-Hot Encoding от scikit-learn
from sklearn.preprocessing import OrdinalEncoder# Импортируем Порядковое кодированиеот scikit-learn

from sklearn.pipeline import Pipeline # Pipeline. Ни добавить, ни убавить

from sklearn.compose import ColumnTransformer # т.н. преобразователь колонок

from sklearn.base import BaseEstimator, TransformerMixin # для создания собственных преобразователей / трансформеров данных

# %%
plt.style.use('dark_background') # для модных черных рисунков

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Набор данных

# %% [markdown]
# Набор данных представляет собой статистику параметров автомобилей на вторичном рынке в Молдавии.
#
# Набор включает ряд категориальных и численных значений, составляющих одну запись (строку). Число записей можно найти как число строк.
#
# Каждый столбец в записи — это отдельный параметр.
#
# Среди указанных параметров приведен целевой для задачи предсказания (регрессии) - цена автомобиля.
#
#  Также среди параметров есть целевой для задачи классификации - тип трансмиссии.
#
#  Последняя задача может быть рассмотрена, например, как пример задачи на заполнение пропусков (если продавец не указал соответствующий параметр).

# %% [markdown]
# # Загрузка данных

# %% [markdown]
# Загружаем наши данные из файла по прямой ссылке на git-hub

# %%
DF = pd.read_csv('https://raw.githubusercontent.com/dayekb/mpti_ml/main/data/cars_moldova_no_dup_no_outliers.csv', delimiter = ',')
DF
# Out:
#              Make         Model  Year      Style  Distance  \
# 0          Toyota         Prius  2011  Hatchback  195000.0
# 1         Renault  Grand Scenic  2014  Universal  135000.0
# 2         Renault        Laguna  2012  Universal  110000.0
# 3            Opel         Astra  2006  Universal  200000.0
# 4        Mercedes          Vito  2000   Microvan  300000.0
# ...           ...           ...   ...        ...       ...
# 32480  Volkswagen        Passat  2016      Sedan   88000.0
# 32481  Land Rover    Freelander  2002  Crossover  225000.0
# 32482       Dacia     Logan Mcv  2015  Universal   89000.0
# 32483       Mazda             6  2006      Combi  370000.0
# 32484     Renault  Grand Scenic  2006    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 0                    1800.0        Hybrid    Automatic       7750.0
# 1                    1500.0        Diesel       Manual       8550.0
# 2                    1500.0        Diesel       Manual       6550.0
# 3                    1600.0  Metan/Propan       Manual       4100.0
# 4                    2200.0        Diesel       Manual       3490.0
# ...                     ...           ...          ...          ...
# 32480                1800.0        Petrol    Automatic      11500.0
# 32481                1800.0  Metan/Propan       Manual       4400.0
# 32482                1500.0        Diesel       Manual       7000.0
# 32483                2000.0        Diesel       Manual       4000.0
# 32484                1500.0        Diesel       Manual       4000.0
#
# [32485 rows x 9 columns]

# %% [markdown]
# Список числовых и категориальных данных

# %%
cat_columns = ['Make', 'Model', 'Style', 'Fuel_type', 'Transmission']
num_columns = ['Year', 'Distance', 'Engine_capacity(cm3)', 'Price(euro)']

# %% [markdown]
# Предварительная обработка из [раннего блокнота](https://colab.research.google.com/drive/1es_OrShFiuaeOnlPjX2B1geHDM-XfofM?usp=sharing)
#
# Из предварительной обработки исключена колонка `Price(euro)`, поскольку она является целевой меткой и будет обработана отдельно

# %%
class QuantileReplacer(BaseEstimator, TransformerMixin):
    def __init__(self, threshold=0.05):
        self.threshold = threshold
        self.quantiles = {}

    def fit(self, X, y=None):
        for col in X.select_dtypes(include='number'):
            low_quantile = X[col].quantile(self.threshold)
            high_quantile = X[col].quantile(1 - self.threshold)
            self.quantiles[col] = (low_quantile, high_quantile)
        return self

    def transform(self, X):
        X_copy = X.copy()
        for col in X.select_dtypes(include='number'):
            low_quantile, high_quantile = self.quantiles[col]
            rare_mask = ((X[col] < low_quantile) | (X[col] > high_quantile))
            if rare_mask.any():
                rare_values = X_copy.loc[rare_mask, col]
                replace_value = np.mean([low_quantile, high_quantile])
                if rare_values.mean() > replace_value:
                    X_copy.loc[rare_mask, col] = high_quantile
                else:
                    X_copy.loc[rare_mask, col] = low_quantile
        return X_copy

# %%
class RareGrouper(BaseEstimator, TransformerMixin):
    def __init__(self, threshold=0.05, other_value='Other'):
        self.threshold = threshold
        self.other_value = other_value
        self.freq_dict = {}

    def fit(self, X, y=None):
        for col in X.select_dtypes(include=['object']):
            freq = X[col].value_counts(normalize=True)
            self.freq_dict[col] = freq[freq >= self.threshold].index.tolist()
        return self

    def transform(self, X, y=None):
        X_copy = X.copy()
        for col in X.select_dtypes(include=['object']):
            X_copy[col] = X_copy[col].apply(lambda x: x if x in self.freq_dict[col] else self.other_value)
        return X_copy

# %%
num_pipe_distance = Pipeline([
    ('QuantReplace', QuantileReplacer(threshold=0.01, )),
    ('scaler', StandardScaler())
])

num_distance = ['Distance']

num_pipe_engine = Pipeline([
    ('scaler', StandardScaler())
])

num_engine = ['Engine_capacity(cm3)']

num_pipe_year = Pipeline([
    ('power', PowerTransformer())
])

num_year = ['Year']

cat_pipe_transmission = Pipeline([
    ('encoder', OrdinalEncoder())

])

cat_transmission = ['Transmission']

cat_pipe_style_fuel = Pipeline([
    ('encoder', OneHotEncoder(drop='if_binary', handle_unknown='ignore', sparse_output=False))

])

cat_style_fuel = ['Style', 'Fuel_type']

cat_pipe_make = Pipeline([
    ('replace_rare', RareGrouper(threshold=0.001, other_value='Other')),
    ('encoder', OneHotEncoder(drop='if_binary', handle_unknown='ignore', sparse_output=False))
])

cat_make = ['Make']

cat_pipe_model = Pipeline([
    ('replace_rare', RareGrouper(threshold=0.0001, other_value='Other')),
    ('encoder', OneHotEncoder(drop='if_binary', handle_unknown='ignore', sparse_output=False))
])

cat_model = ['Model']

# Сделаем отдельно Pipeline с числовыми признаками
preprocessors_num = ColumnTransformer(transformers=[
    ('num_distance', num_pipe_distance, num_distance),
    ('num_engine', num_pipe_engine, num_engine),
    ('num_year', num_pipe_year, num_year),
])

# и Pipeline со всеми признаками
preprocessors_all = ColumnTransformer(transformers=[
    ('num_distance', num_pipe_distance, num_distance),
    ('num_engine', num_pipe_engine, num_engine),
    ('num_year', num_pipe_year, num_year),
    ('cat_transmission', cat_pipe_transmission, cat_transmission),
    ('cat_style_fuel', cat_pipe_style_fuel, cat_style_fuel),
    ('cat_make', cat_pipe_make, cat_make),
    ('cat_model', cat_pipe_model, cat_model),
])

# %%
# объединяем названия колонок в один список (важен порядок как в ColumnTransformer)
columns_num = np.hstack([num_distance,
                    num_engine,
                    num_year,])

# %% [markdown]
# # Регрессия Методом к-Ближайших Соседей

# %%
from sklearn.neighbors import KNeighborsRegressor # Регрессия К-Ближайших соседей от scikit-learn

from sklearn.model_selection import train_test_split#  функция разбиения на тренировочную и тестовую выборку
# в исполнении scikit-learn
from sklearn.model_selection import ShuffleSplit # при кросс-валидации случайно перемешиваем данные
from sklearn.model_selection import cross_validate # функция кросс-валидации от Scikit-learn

from sklearn.metrics import mean_squared_error as mse # метрика MSE от Scikit-learn
from sklearn.metrics import r2_score # коэффициент детерминации  от Scikit-learn

from sklearn.metrics import PredictionErrorDisplay # Класс визуализации ошибок модели

# %% [markdown]
# **Считываем данные, разбиваем на тестовую и тренировочную**

# %%
# не забываем удалить целевую переменную цену из признаков
X,y = DF.drop(columns = ['Price(euro)']), DF['Price(euro)']

# разбиваем на тестовую и валидационную
X_train, X_val, y_train, y_val = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=42)

# %% [markdown]
# # Оценим модель с использованием только числовых данных

# %% [markdown]
# **Преобразуем данные**

# %%
# Сначала обучаем на тренировочных данных
X_train_prep = preprocessors_num.fit_transform(X_train)
# потом на валидационной
X_val_prep = preprocessors_num.transform(X_val)

# %% [markdown]
# **Обучаем модель**

# %% [markdown]
# Стандартная уже для нас рутина
#
# * Создаем объект класса
# * "Обучаем" через `.fit`

# %%
model = KNeighborsRegressor(n_neighbors = 3,
                            weights = 'distance')

model.fit(X_train_prep, y_train);

# %% [markdown]
# ## Оценка метрик

# %%
def calculate_metric(model_pipe, X, y, metric = r2_score):
    """Расчет метрики.
    Параметры:
    ===========
    model_pipe: модель или pipeline
    X: признаки
    y: истинные значения
    metric: метрика (r2 - по умолчанию)
    """
    y_model = model_pipe.predict(X)
    return metric(y, y_model)

# %%
print(f"r2 на тренировочной выборке: {calculate_metric(model, X_train_prep, y_train):.4f}")
print(f"r2 на валидационной выборке: {calculate_metric(model, X_val_prep, y_val):.4f}")

print(f"mse на тренировочной выборке: {calculate_metric(model, X_train_prep, y_train, mse):.4f}")
print(f"mse на валидационной выборке: {calculate_metric(model, X_val_prep, y_val, mse):.4f}")
# Out:
# r2 на тренировочной выборке: 0.9724
# r2 на валидационной выборке: 0.7001
# mse на тренировочной выборке: 1676989.1684
# mse на валидационной выборке: 18881951.3985

# %% [markdown]
# ## Кросс-валидация

# %%
def cross_validation (X, y, model, scoring, cv_rule):
    """Расчет метрик на кросс-валидации.
    Параметры:
    ===========
    model: модель или pipeline
    X: признаки
    y: истинные значения
    scoring: словарь метрик
    cv_rule: правило кросс-валидации
    """
    scores = cross_validate(model,X, y,
                      scoring=scoring, cv=cv_rule )
    print('Ошибка на кросс-валидации')
    DF_score = pd.DataFrame(scores)
    display(DF_score)
    print('\n')
    print(DF_score.mean()[2:])

# %%
scoring_reg = {'R2': 'r2',
           '-MSE': 'neg_mean_squared_error',
           '-MAE': 'neg_mean_absolute_error',
           '-Max': 'max_error'}

# %%
cross_validation (X_train_prep, y_train,
                  model,
                  scoring_reg,
                  ShuffleSplit(n_splits=5, random_state= 42))
# Out:
# Ошибка на кросс-валидации
#    fit_time  score_time   test_R2     test_-MSE    test_-MAE     test_-Max
# 0  0.050628    0.046247  0.697832 -1.789194e+07 -2574.931471 -30604.821996
# 1  0.029616    0.082993  0.694177 -1.977338e+07 -2663.497927 -36972.283630
# 2  0.101485    0.120070  0.672858 -2.008407e+07 -2610.604525 -40016.666667
# 3  0.056189    0.031259  0.695034 -1.821424e+07 -2631.002053 -27500.000000
# 4  0.028128    0.023187  0.678072 -1.885356e+07 -2585.080959 -42116.039382
# test_R2      6.875945e-01
# test_-MSE   -1.896344e+07
# test_-MAE   -2.613023e+03
# test_-Max   -3.544196e+04
# dtype: float64

# %% [markdown]
# ## Визуализация ошибок от scikit-learn

# %%
PredictionErrorDisplay.from_predictions(
    y_val,
    model.predict(X_val_prep),
    kind="actual_vs_predicted",
    scatter_kwargs={"alpha": 0.5},
    line_kwargs = {"color" : 'white'}

);

# %% [markdown]
# ## Поиск Лучших Гиперпараметров с Помощью Рандомизированного Поиска

# %%
from sklearn.model_selection import RandomizedSearchCV # для поиска при случайном сэмплировании гиперпараметров
import scipy.stats as stats # статистические функции библиотеки scipy

# %%
# словарь гиперпараметров в виде
# обозначение гиперпараметров : из какого распределения сэмплируем
# обозначение должно "досимвольно" совпадать с тем что в документации
parameters = {'n_neighbors':stats.randint(1,50), # задаем распределение как равномерное от 1 до 50
              'weights':['uniform', 'distance']}

# количество итераций
n_iter_search = 20

kNN_search = RandomizedSearchCV(estimator = KNeighborsRegressor(),  # оптимизируем нашу модель
                                verbose = 3,  # 3 чтобы он всё подробно расписал, если не интересно - пишем 0
                          param_distributions=parameters , # что оптимизируем - берем из словарика
                          cv=ShuffleSplit(n_splits=5, random_state=42), # указываем тип кросс-валидации
                          n_iter = n_iter_search # количество итераций
                          )

# %% [markdown]
# Стандартное обучение через метод `.fit()`
#
# В этом случае он будет тестировать для выбранного `estimator` `n_iter` комбинации гиперпараметров по распределению из `param_distributions`

# %%
kNN_search.fit(X_train_prep, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END ..n_neighbors=24, weights=distance;, score=0.751 total time=   0.2s
# [CV 2/5] END ..n_neighbors=24, weights=distance;, score=0.742 total time=   0.2s
# [CV 3/5] END ..n_neighbors=24, weights=distance;, score=0.729 total time=   0.1s
# [CV 4/5] END ..n_neighbors=24, weights=distance;, score=0.745 total time=   0.1s
# [CV 5/5] END ..n_neighbors=24, weights=distance;, score=0.717 total time=   0.4s
# [CV 1/5] END ..n_neighbors=37, weights=distance;, score=0.752 total time=   0.2s
# [CV 2/5] END ..n_neighbors=37, weights=distance;, score=0.746 total time=   0.2s
# [CV 3/5] END ..n_neighbors=37, weights=distance;, score=0.734 total time=   0.2s
# [CV 4/5] END ..n_neighbors=37, weights=distance;, score=0.747 total time=   0.1s
# [CV 5/5] END ..n_neighbors=37, weights=distance;, score=0.716 total time=   0.2s
# [CV 1/5] END ..n_neighbors=15, weights=distance;, score=0.748 total time=   0.2s
# [CV 2/5] END ..n_neighbors=15, weights=distance;, score=0.735 total time=   0.1s
# [CV 3/5] END ..n_neighbors=15, weights=distance;, score=0.724 total time=   0.1s
# [CV 4/5] END ..n_neighbors=15, weights=distance;, score=0.740 total time=   0.1s
# [CV 5/5] END ..n_neighbors=15, weights=distance;, score=0.715 total time=   0.1s
# [CV 1/5] END ...n_neighbors=18, weights=uniform;, score=0.781 total time=   0.1s
# [CV 2/5] END ...n_neighbors=18, weights=uniform;, score=0.775 total time=   0.2s
# [CV 3/5] END ...n_neighbors=18, weights=uniform;, score=0.750 total time=   0.2s
# [CV 4/5] END ...n_neighbors=18, weights=uniform;, score=0.767 total time=   0.1s
# [CV 5/5] END ...n_neighbors=18, weights=uniform;, score=0.748 total time=   0.1s
# [CV 1/5] END ..n_neighbors=17, weights=distance;, score=0.750 total time=   0.1s
# [CV 2/5] END ..n_neighbors=17, weights=distance;, score=0.736 total time=   0.1s
# [CV 3/5] END ..n_neighbors=17, weights=distance;, score=0.726 total time=   0.2s
# [CV 4/5] END ..n_neighbors=17, weights=distance;, score=0.741 total time=   0.2s
# [CV 5/5] END ..n_neighbors=17, weights=distance;, score=0.715 total time=   0.1s
# [CV 1/5] END ...n_neighbors=31, weights=uniform;, score=0.775 total time=   0.3s
# [CV 2/5] END ...n_neighbors=31, weights=uniform;, score=0.783 total time=   0.3s
# [CV 3/5] END ...n_neighbors=31, weights=uniform;, score=0.753 total time=   0.1s
# [CV 4/5] END ...n_neighbors=31, weights=uniform;, score=0.765 total time=   0.2s
# [CV 5/5] END ...n_neighbors=31, weights=uniform;, score=0.746 total time=   0.4s
# [CV 1/5] END ...n_neighbors=43, weights=uniform;, score=0.778 total time=   0.2s
# [CV 2/5] END ...n_neighbors=43, weights=uniform;, score=0.781 total time=   0.1s
# [CV 3/5] END ...n_neighbors=43, weights=uniform;, score=0.750 total time=   0.1s
# [CV 4/5] END ...n_neighbors=43, weights=uniform;, score=0.764 total time=   0.1s
# [CV 5/5] END ...n_neighbors=43, weights=uniform;, score=0.744 total time=   0.1s
# [CV 1/5] END ...n_neighbors=11, weights=uniform;, score=0.774 total time=   0.1s
# [CV 2/5] END ...n_neighbors=11, weights=uniform;, score=0.768 total time=   0.1s
# [CV 3/5] END ...n_neighbors=11, weights=uniform;, score=0.747 total time=   0.1s
# [CV 4/5] END ...n_neighbors=11, weights=uniform;, score=0.762 total time=   0.1s
# [CV 5/5] END ...n_neighbors=11, weights=uniform;, score=0.743 total time=   0.1s
# [CV 1/5] END ..n_neighbors=18, weights=distance;, score=0.749 total time=   0.1s
# [CV 2/5] END ..n_neighbors=18, weights=distance;, score=0.737 total time=   0.1s
# [CV 3/5] END ..n_neighbors=18, weights=distance;, score=0.726 total time=   0.1s
# [CV 4/5] END ..n_neighbors=18, weights=distance;, score=0.742 total time=   0.1s
# [CV 5/5] END ..n_neighbors=18, weights=distance;, score=0.716 total time=   0.1s
# [CV 1/5] END ..n_neighbors=30, weights=distance;, score=0.751 total time=   0.1s
# [CV 2/5] END ..n_neighbors=30, weights=distance;, score=0.744 total time=   0.1s
# [CV 3/5] END ..n_neighbors=30, weights=distance;, score=0.733 total time=   0.1s
# [CV 4/5] END ..n_neighbors=30, weights=distance;, score=0.746 total time=   0.1s
# [CV 5/5] END ..n_neighbors=30, weights=distance;, score=0.716 total time=   0.1s
# [CV 1/5] END ..n_neighbors=44, weights=distance;, score=0.754 total time=   0.1s
# [CV 2/5] END ..n_neighbors=44, weights=distance;, score=0.746 total time=   0.2s
# [CV 3/5] END ..n_neighbors=44, weights=distance;, score=0.735 total time=   0.2s
# [CV 4/5] END ..n_neighbors=44, weights=distance;, score=0.747 total time=   0.2s
# [CV 5/5] END ..n_neighbors=44, weights=distance;, score=0.717 total time=   0.3s
# [CV 1/5] END ..n_neighbors=47, weights=distance;, score=0.754 total time=   0.2s
# [CV 2/5] END ..n_neighbors=47, weights=distance;, score=0.746 total time=   0.2s
# [CV 3/5] END ..n_neighbors=47, weights=distance;, score=0.735 total time=   0.2s
# [CV 4/5] END ..n_neighbors=47, weights=distance;, score=0.748 total time=   0.2s
# [CV 5/5] END ..n_neighbors=47, weights=distance;, score=0.717 total time=   0.3s
# [CV 1/5] END ...n_neighbors=43, weights=uniform;, score=0.778 total time=   0.2s
# [CV 2/5] END ...n_neighbors=43, weights=uniform;, score=0.781 total time=   0.2s
# [CV 3/5] END ...n_neighbors=43, weights=uniform;, score=0.750 total time=   0.3s
# [CV 4/5] END ...n_neighbors=43, weights=uniform;, score=0.764 total time=   0.2s
# [CV 5/5] END ...n_neighbors=43, weights=uniform;, score=0.744 total time=   0.3s
# [CV 1/5] END ..n_neighbors=32, weights=distance;, score=0.752 total time=   0.2s
# [CV 2/5] END ..n_neighbors=32, weights=distance;, score=0.745 total time=   0.2s
# [CV 3/5] END ..n_neighbors=32, weights=distance;, score=0.733 total time=   0.2s
# [CV 4/5] END ..n_neighbors=32, weights=distance;, score=0.746 total time=   0.2s
# [CV 5/5] END ..n_neighbors=32, weights=distance;, score=0.716 total time=   0.3s
# [CV 1/5] END ...n_neighbors=6, weights=distance;, score=0.727 total time=   0.1s
# [CV 2/5] END ...n_neighbors=6, weights=distance;, score=0.719 total time=   0.2s
# [CV 3/5] END ...n_neighbors=6, weights=distance;, score=0.703 total time=   0.2s
# [CV 4/5] END ...n_neighbors=6, weights=distance;, score=0.724 total time=   0.2s
# [CV 5/5] END ...n_neighbors=6, weights=distance;, score=0.701 total time=   0.1s
# [CV 1/5] END ..n_neighbors=11, weights=distance;, score=0.741 total time=   0.1s
# [CV 2/5] END ..n_neighbors=11, weights=distance;, score=0.730 total time=   0.1s
# [CV 3/5] END ..n_neighbors=11, weights=distance;, score=0.719 total time=   0.1s
# [CV 4/5] END ..n_neighbors=11, weights=distance;, score=0.738 total time=   0.1s
# [CV 5/5] END ..n_neighbors=11, weights=distance;, score=0.711 total time=   0.1s
# [CV 1/5] END ...n_neighbors=1, weights=distance;, score=0.620 total time=   0.0s
# [CV 2/5] END ...n_neighbors=1, weights=distance;, score=0.620 total time=   0.0s
# [CV 3/5] END ...n_neighbors=1, weights=distance;, score=0.587 total time=   0.0s
# [CV 4/5] END ...n_neighbors=1, weights=distance;, score=0.594 total time=   0.1s
# [CV 5/5] END ...n_neighbors=1, weights=distance;, score=0.614 total time=   0.1s
# [CV 1/5] END ..n_neighbors=47, weights=distance;, score=0.754 total time=   0.2s
# [CV 2/5] END ..n_neighbors=47, weights=distance;, score=0.746 total time=   0.1s
# [CV 3/5] END ..n_neighbors=47, weights=distance;, score=0.735 total time=   0.1s
# [CV 4/5] END ..n_neighbors=47, weights=distance;, score=0.748 total time=   0.1s
# [CV 5/5] END ..n_neighbors=47, weights=distance;, score=0.717 total time=   0.1s
# [CV 1/5] END ..n_neighbors=14, weights=distance;, score=0.747 total time=   0.1s
# [CV 2/5] END ..n_neighbors=14, weights=distance;, score=0.734 total time=   0.1s
# [CV 3/5] END ..n_neighbors=14, weights=distance;, score=0.723 total time=   0.1s
# [CV 4/5] END ..n_neighbors=14, weights=distance;, score=0.739 total time=   0.1s
# [CV 5/5] END ..n_neighbors=14, weights=distance;, score=0.714 total time=   0.1s
# [CV 1/5] END ..n_neighbors=11, weights=distance;, score=0.741 total time=   0.1s
# [CV 2/5] END ..n_neighbors=11, weights=distance;, score=0.730 total time=   0.1s
# [CV 3/5] END ..n_neighbors=11, weights=distance;, score=0.719 total time=   0.1s
# [CV 4/5] END ..n_neighbors=11, weights=distance;, score=0.738 total time=   0.1s
# [CV 5/5] END ..n_neighbors=11, weights=distance;, score=0.711 total time=   0.1s
# RandomizedSearchCV(cv=ShuffleSplit(n_splits=5, random_state=42, test_size=None, train_size=None),
#                    estimator=KNeighborsRegressor(), n_iter=20,
#                    param_distributions={'n_neighbors': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7f92ff4c2e50>,
#                                         'weights': ['uniform', 'distance']},
#                    verbose=3)

# %% [markdown]
# Лучший Кандидат

# %%
kNN_search.best_estimator_
# Out:
# KNeighborsRegressor(n_neighbors=31)

# %%
kNNbest=kNN_search.best_estimator_

kNNbest.fit(X_train_prep, y_train);

# %%
print(f"r2 на тренировочной выборке: {calculate_metric(kNNbest, X_train_prep, y_train):.4f}")
print(f"r2 на валидационной выборке: {calculate_metric(kNNbest, X_val_prep, y_val):.4f}")

print(f"mse на тренировочной выборке: {calculate_metric(kNNbest, X_train_prep, y_train, mse):.4f}")
print(f"mse на валидационной выборке: {calculate_metric(kNNbest, X_val_prep, y_val, mse):.4f}")
# Out:
# r2 на тренировочной выборке: 0.7703
# r2 на валидационной выборке: 0.7699
# mse на тренировочной выборке: 13970346.2033
# mse на валидационной выборке: 14483507.5500

# %% [markdown]
# **Рассмотрим результаты перебора**

# %%
DF_reg=pd.DataFrame(kNN_search.cv_results_)
DF = DF_reg[['param_n_neighbors','param_weights',
             'mean_test_score', 'std_test_score', 'rank_test_score']]
cm = sns.light_palette("purple", as_cmap=True)
hl = DF.sort_values(by = 'rank_test_score').style.background_gradient(cmap=cm)
hl
# Out:
# <style type="text/css">
# #T_dc1be_row0_col0 {
#   background-color: #a854a8;
#   color: #f1f1f1;
# }
# #T_dc1be_row0_col2, #T_dc1be_row1_col2, #T_dc1be_row2_col3, #T_dc1be_row3_col3, #T_dc1be_row5_col0, #T_dc1be_row6_col0, #T_dc1be_row19_col4 {
#   background-color: #800080;
#   color: #f1f1f1;
# }
# #T_dc1be_row0_col3 {
#   background-color: #983398;
#   color: #f1f1f1;
# }
# #T_dc1be_row0_col4, #T_dc1be_row18_col3, #T_dc1be_row19_col0, #T_dc1be_row19_col2 {
#   background-color: #f3f0f3;
#   color: #000000;
# }
# #T_dc1be_row1_col0, #T_dc1be_row7_col4, #T_dc1be_row12_col0 {
#   background-color: #c897c8;
#   color: #f1f1f1;
# }
# #T_dc1be_row1_col3 {
#   background-color: #b267b2;
#   color: #f1f1f1;
# }
# #T_dc1be_row1_col4 {
#   background-color: #ede3ed;
#   color: #000000;
# }
# #T_dc1be_row2_col0, #T_dc1be_row3_col0 {
#   background-color: #8a158a;
#   color: #f1f1f1;
# }
# #T_dc1be_row2_col2, #T_dc1be_row3_col2 {
#   background-color: #800180;
#   color: #f1f1f1;
# }
# #T_dc1be_row2_col4, #T_dc1be_row3_col4 {
#   background-color: #e7d7e7;
#   color: #000000;
# }
# #T_dc1be_row4_col0, #T_dc1be_row16_col0, #T_dc1be_row17_col0 {
#   background-color: #dabcda;
#   color: #000000;
# }
# #T_dc1be_row4_col2 {
#   background-color: #840884;
#   color: #f1f1f1;
# }
# #T_dc1be_row4_col3 {
#   background-color: #cda1cd;
#   color: #000000;
# }
# #T_dc1be_row4_col4 {
#   background-color: #dbbedb;
#   color: #000000;
# }
# #T_dc1be_row5_col2, #T_dc1be_row6_col2, #T_dc1be_row19_col3 {
#   background-color: #922592;
#   color: #f1f1f1;
# }
# #T_dc1be_row5_col3, #T_dc1be_row6_col3 {
#   background-color: #ad5fad;
#   color: #f1f1f1;
# }
# #T_dc1be_row5_col4, #T_dc1be_row6_col4 {
#   background-color: #d5b1d5;
#   color: #000000;
# }
# #T_dc1be_row7_col0 {
#   background-color: #870f87;
#   color: #f1f1f1;
# }
# #T_dc1be_row7_col2, #T_dc1be_row16_col4, #T_dc1be_row17_col4 {
#   background-color: #922692;
#   color: #f1f1f1;
# }
# #T_dc1be_row7_col3 {
#   background-color: #b268b2;
#   color: #f1f1f1;
# }
# #T_dc1be_row8_col0 {
#   background-color: #993499;
#   color: #f1f1f1;
# }
# #T_dc1be_row8_col2 {
#   background-color: #922792;
#   color: #f1f1f1;
# }
# #T_dc1be_row8_col3 {
#   background-color: #b166b1;
#   color: #f1f1f1;
# }
# #T_dc1be_row8_col4 {
#   background-color: #c38bc3;
#   color: #f1f1f1;
# }
# #T_dc1be_row9_col0 {
#   background-color: #a54ea5;
#   color: #f1f1f1;
# }
# #T_dc1be_row9_col2, #T_dc1be_row10_col2 {
#   background-color: #932793;
#   color: #f1f1f1;
# }
# #T_dc1be_row9_col3 {
#   background-color: #bc7dbc;
#   color: #f1f1f1;
# }
# #T_dc1be_row9_col4 {
#   background-color: #bc7ebc;
#   color: #f1f1f1;
# }
# #T_dc1be_row10_col0, #T_dc1be_row12_col4 {
#   background-color: #aa58aa;
#   color: #f1f1f1;
# }
# #T_dc1be_row10_col3 {
#   background-color: #ba79ba;
#   color: #f1f1f1;
# }
# #T_dc1be_row10_col4 {
#   background-color: #b672b6;
#   color: #f1f1f1;
# }
# #T_dc1be_row11_col0 {
#   background-color: #b977b9;
#   color: #f1f1f1;
# }
# #T_dc1be_row11_col2 {
#   background-color: #942994;
#   color: #f1f1f1;
# }
# #T_dc1be_row11_col3 {
#   background-color: #c085c0;
#   color: #f1f1f1;
# }
# #T_dc1be_row11_col4 {
#   background-color: #b065b0;
#   color: #f1f1f1;
# }
# #T_dc1be_row12_col2, #T_dc1be_row13_col2 {
#   background-color: #962e96;
#   color: #f1f1f1;
# }
# #T_dc1be_row12_col3 {
#   background-color: #d3aed3;
#   color: #000000;
# }
# #T_dc1be_row13_col0 {
#   background-color: #cb9ccb;
#   color: #f1f1f1;
# }
# #T_dc1be_row13_col3 {
#   background-color: #cfa5cf;
#   color: #000000;
# }
# #T_dc1be_row13_col4, #T_dc1be_row18_col2 {
#   background-color: #a44ba4;
#   color: #f1f1f1;
# }
# #T_dc1be_row14_col0 {
#   background-color: #d0a7d0;
#   color: #000000;
# }
# #T_dc1be_row14_col2 {
#   background-color: #973097;
#   color: #f1f1f1;
# }
# #T_dc1be_row14_col3 {
#   background-color: #d8b7d8;
#   color: #000000;
# }
# #T_dc1be_row14_col4 {
#   background-color: #9e3f9e;
#   color: #f1f1f1;
# }
# #T_dc1be_row15_col0 {
#   background-color: #d2acd2;
#   color: #000000;
# }
# #T_dc1be_row15_col2, #T_dc1be_row15_col4 {
#   background-color: #983298;
#   color: #f1f1f1;
# }
# #T_dc1be_row15_col3 {
#   background-color: #d5b2d5;
#   color: #000000;
# }
# #T_dc1be_row16_col2, #T_dc1be_row17_col2 {
#   background-color: #9b379b;
#   color: #f1f1f1;
# }
# #T_dc1be_row16_col3, #T_dc1be_row17_col3 {
#   background-color: #e3cfe3;
#   color: #000000;
# }
# #T_dc1be_row18_col0 {
#   background-color: #e7d6e7;
#   color: #000000;
# }
# #T_dc1be_row18_col4 {
#   background-color: #860c86;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dc1be" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc1be_level0_col0" class="col_heading level0 col0" >param_n_neighbors</th>
#       <th id="T_dc1be_level0_col1" class="col_heading level0 col1" >param_weights</th>
#       <th id="T_dc1be_level0_col2" class="col_heading level0 col2" >mean_test_score</th>
#       <th id="T_dc1be_level0_col3" class="col_heading level0 col3" >std_test_score</th>
#       <th id="T_dc1be_level0_col4" class="col_heading level0 col4" >rank_test_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc1be_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_dc1be_row0_col0" class="data row0 col0" >31</td>
#       <td id="T_dc1be_row0_col1" class="data row0 col1" >uniform</td>
#       <td id="T_dc1be_row0_col2" class="data row0 col2" >0.764334</td>
#       <td id="T_dc1be_row0_col3" class="data row0 col3" >0.013681</td>
#       <td id="T_dc1be_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_dc1be_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_dc1be_row1_col0" class="data row1 col0" >18</td>
#       <td id="T_dc1be_row1_col1" class="data row1 col1" >uniform</td>
#       <td id="T_dc1be_row1_col2" class="data row1 col2" >0.764189</td>
#       <td id="T_dc1be_row1_col3" class="data row1 col3" >0.012879</td>
#       <td id="T_dc1be_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_dc1be_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_dc1be_row2_col0" class="data row2 col0" >43</td>
#       <td id="T_dc1be_row2_col1" class="data row2 col1" >uniform</td>
#       <td id="T_dc1be_row2_col2" class="data row2 col2" >0.763389</td>
#       <td id="T_dc1be_row2_col3" class="data row2 col3" >0.014471</td>
#       <td id="T_dc1be_row2_col4" class="data row2 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_dc1be_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_dc1be_row3_col0" class="data row3 col0" >43</td>
#       <td id="T_dc1be_row3_col1" class="data row3 col1" >uniform</td>
#       <td id="T_dc1be_row3_col2" class="data row3 col2" >0.763389</td>
#       <td id="T_dc1be_row3_col3" class="data row3 col3" >0.014471</td>
#       <td id="T_dc1be_row3_col4" class="data row3 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_dc1be_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_dc1be_row4_col0" class="data row4 col0" >11</td>
#       <td id="T_dc1be_row4_col1" class="data row4 col1" >uniform</td>
#       <td id="T_dc1be_row4_col2" class="data row4 col2" >0.758908</td>
#       <td id="T_dc1be_row4_col3" class="data row4 col3" >0.012000</td>
#       <td id="T_dc1be_row4_col4" class="data row4 col4" >5</td>
#     </tr>
#     <tr>
#       <th id="T_dc1be_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_dc1be_row5_col0" class="data row5 col0" >47</td>
#       <td id="T_dc1be_row5_col1" class="data row5 col1" >distance</td>
#       <td id="T_dc1be_row5_col2" class="data row5 col2" >0.740120</td>
#       <td id="T_dc1be_row5_col3" class="data row5 col3" >0.013012</td>
#       <td id="T_dc1be_row5_col4" class="data row5 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dc1be_level0_row6" class="row_heading level0 row6" >17</th>
#       <td id="T_dc1be_row6_col0" class="data row6 col0" >47</td>
#       <td id="T_dc1be_row6_col1" class="data row6 col1" >distance</td>
#       <td id="T_dc1be_row6_col2" class="data row6 col2" >0.740120</td>
#       <td id="T_dc1be_row6_col3" class="data row6 col3" >0.013012</td>
#       <td id="T_dc1be_row6_col4" class="data row6 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dc1be_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_dc1be_row7_col0" class="data row7 col0" >44</td>

# %% [markdown]
# Небольшие выводы
#
# * в сравнении с линейной регрессией в тех же условиях (только числовые признаки, целевая переменная не предобработана) модель к-ближайших соседей лучше (метрика r2 на кроссвалидации `0.76`против `0.45`)
# * предпочительней тип весов `uniform`, хотя стоит отметить большую стаблильность типа весов `distance` (меньше разброс оценок)
# * рост числа соседей после `13` не несет значительный вклад
#
# * можно сказать, что в целом нет значительных ошибок как для небольших, так и для больших значений цены

# %% [markdown]
# # Оценим влияние предварительной обработки целевой переменной

# %% [markdown]
# Мы забыли поправить целевую метку - она же была не нормальная (в смысле нормального распределения)
#
# И решение - `TransformedTargetRegressor`

# %%
from sklearn.compose import TransformedTargetRegressor

# %%
pipe_num_transform = Pipeline([
    ('preprocessors', preprocessors_num),
    ('model', TransformedTargetRegressor( regressor=KNeighborsRegressor(n_neighbors = 14),
    transformer=PowerTransformer())
    )
])

# %%
pipe_num_transform.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessors',
#                  ColumnTransformer(transformers=[('num_distance',
#                                                   Pipeline(steps=[('QuantReplace',
#                                                                    QuantileReplacer(threshold=0.01)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Distance']),
#                                                  ('num_engine',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Engine_capacity(cm3)']),
#                                                  ('num_year',
#                                                   Pipeline(steps=[('power',
#                                                                    PowerTransformer())]),
#                                                   ['Year'])])),
#                 ('model',
#                  TransformedTargetRegressor(regressor=KNeighborsRegressor(n_neighbors=14),
#                                             transformer=PowerTransformer()))])

# %%
print(f"r2 на тренировочной выборке: {calculate_metric(pipe_num_transform, X_train, y_train):.4f}")
print(f"r2 на валидационной выборке: {calculate_metric(pipe_num_transform, X_val, y_val):.4f}")

print(f"mse на тренировочной выборке: {calculate_metric(pipe_num_transform, X_train, y_train, mse):.4f}")
print(f"mse на валидационной выборке: {calculate_metric(pipe_num_transform, X_val, y_val, mse):.4f}")
# Out:
# r2 на тренировочной выборке: 0.7794
# r2 на валидационной выборке: 0.7599
# mse на тренировочной выборке: 13417037.6836
# mse на валидационной выборке: 15114743.8814

# %%
cross_validation (X_train, y_train,
                  pipe_num_transform,
                  scoring_reg,
                  ShuffleSplit(n_splits=5, random_state= 42))
# Out:
# Ошибка на кросс-валидации
#    fit_time  score_time   test_R2     test_-MSE    test_-MAE     test_-Max
# 0  0.123083    0.035998  0.779605 -1.304999e+07 -2266.693583 -31224.780509
# 1  0.114146    0.037099  0.768636 -1.495916e+07 -2339.315625 -38799.362801
# 2  0.122151    0.033150  0.749713 -1.536573e+07 -2363.473503 -39916.815058
# 3  0.125464    0.032287  0.753744 -1.470771e+07 -2367.746447 -29238.263915
# 4  0.119867    0.033548  0.738782 -1.529811e+07 -2324.323162 -44605.099207
# test_R2      7.580961e-01
# test_-MSE   -1.467614e+07
# test_-MAE   -2.332310e+03
# test_-Max   -3.675686e+04
# dtype: float64

# %%
PredictionErrorDisplay.from_predictions(
    y_val,
    pipe_num_transform.predict(X_val),
    kind="actual_vs_predicted",
    scatter_kwargs={"alpha": 0.5},
    line_kwargs = {"color" : 'white'}

);

# %% [markdown]
# ## Поиск Лучших Гиперпараметров по Сетке Параметров

# %%
from sklearn.model_selection import GridSearchCV # для поиска по сетке гиперпараметров

from sklearn.metrics import make_scorer #функция для создания объекта из метрики для использования в кросс-валидации

# %%
pipe_num_transform
# Out:
# Pipeline(steps=[('preprocessors',
#                  ColumnTransformer(transformers=[('num_distance',
#                                                   Pipeline(steps=[('QuantReplace',
#                                                                    QuantileReplacer(threshold=0.01)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Distance']),
#                                                  ('num_engine',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Engine_capacity(cm3)']),
#                                                  ('num_year',
#                                                   Pipeline(steps=[('power',
#                                                                    PowerTransformer())]),
#                                                   ['Year'])])),
#                 ('model',
#                  TransformedTargetRegressor(regressor=KNeighborsRegressor(n_neighbors=14),
#                                             transformer=PowerTransformer()))])

# %%
param_grid = {
    # ВАЖНО: используем "имена", которые есть у компонент Pipeline и разделяем их __ (две земли)
    "preprocessors__num_distance__QuantReplace__threshold": [0, 0.01],
    "model__regressor__n_neighbors": np.arange(1,50,8),
    "model__regressor__weights": ['uniform', 'distance'],
}

# %%
scorer = make_scorer(r2_score)

# %%
Pipe_GS = GridSearchCV(estimator = pipe_num_transform, # оптимизируем наш pipeline
                       param_grid=param_grid , # что оптимизируем - берем из словарика
                       cv=ShuffleSplit(n_splits=5, random_state=42), # указываем тип кросс-валидации
                       scoring = scorer, # указываем метрику которую оптимизируем
                       verbose = 3 # 3 чтобы он всё подробно расписал, если не интересно - пишем 0
                       )
Pipe_GS
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=5, random_state=42, test_size=None, train_size=None),
#              estimator=Pipeline(steps=[('preprocessors',
#                                         ColumnTransformer(transformers=[('num_distance',
#                                                                          Pipeline(steps=[('QuantReplace',
#                                                                                           QuantileReplacer(threshold=0.01)),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['Distance']),
#                                                                         ('num_engine',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          [...
#                                         TransformedTargetRegressor(regressor=KNeighborsRegressor(n_neighbors=14),
#                                                                    transformer=PowerTransformer()))]),
#              param_grid={'model__regressor__n_neighbors': array([ 1,  9, 17, 25, 33, 41, 49]),
#                          'model__regressor__weights': ['uniform', 'distance'],
#                          'preprocessors__num_distance__QuantReplace__threshold': [0,
#                                                                                   0.01]},
#              scoring=make_scorer(r2_score, response_method='predict'),
#              verbose=3)

# %% [markdown]
# Стандартное обучение через метод `.fit()`
#
# В этом случае он будет тестировать для выбранного `estimator` все перечисленные комбинации гиперпараметров / аргументов из `param_grid`

# %%
Pipe_GS.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# [CV 1/5] END model__regressor__n_neighbors=1, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.611 total time=   0.1s
# [CV 2/5] END model__regressor__n_neighbors=1, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.613 total time=   0.1s
# [CV 3/5] END model__regressor__n_neighbors=1, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.576 total time=   0.1s
# [CV 4/5] END model__regressor__n_neighbors=1, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.597 total time=   0.1s
# [CV 5/5] END model__regressor__n_neighbors=1, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.607 total time=   0.1s
# [CV 1/5] END model__regressor__n_neighbors=1, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.615 total time=   0.1s
# [CV 2/5] END model__regressor__n_neighbors=1, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.610 total time=   0.1s
# [CV 3/5] END model__regressor__n_neighbors=1, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.584 total time=   0.1s
# [CV 4/5] END model__regressor__n_neighbors=1, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.598 total time=   0.1s
# [CV 5/5] END model__regressor__n_neighbors=1, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.608 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=1, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.611 total time=   0.1s
# [CV 2/5] END model__regressor__n_neighbors=1, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.613 total time=   0.1s
# [CV 3/5] END model__regressor__n_neighbors=1, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.576 total time=   0.1s
# [CV 4/5] END model__regressor__n_neighbors=1, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.597 total time=   0.1s
# [CV 5/5] END model__regressor__n_neighbors=1, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.607 total time=   0.1s
# [CV 1/5] END model__regressor__n_neighbors=1, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.615 total time=   0.1s
# [CV 2/5] END model__regressor__n_neighbors=1, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.610 total time=   0.1s
# [CV 3/5] END model__regressor__n_neighbors=1, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.584 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=1, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.598 total time=   0.1s
# [CV 5/5] END model__regressor__n_neighbors=1, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.608 total time=   0.1s
# [CV 1/5] END model__regressor__n_neighbors=9, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.769 total time=   0.1s
# [CV 2/5] END model__regressor__n_neighbors=9, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.766 total time=   0.1s
# [CV 3/5] END model__regressor__n_neighbors=9, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.737 total time=   0.1s
# [CV 4/5] END model__regressor__n_neighbors=9, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.751 total time=   0.1s
# [CV 5/5] END model__regressor__n_neighbors=9, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.735 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=9, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.771 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=9, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.765 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=9, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.741 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=9, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.748 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=9, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.736 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=9, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.737 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=9, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.729 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=9, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.713 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=9, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.729 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=9, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.708 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=9, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.737 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=9, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.731 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=9, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.714 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=9, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.729 total time=   0.1s
# [CV 5/5] END model__regressor__n_neighbors=9, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.708 total time=   0.1s
# [CV 1/5] END model__regressor__n_neighbors=17, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.778 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=17, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.772 total time=   0.1s
# [CV 3/5] END model__regressor__n_neighbors=17, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.746 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=17, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.757 total time=   0.1s
# [CV 5/5] END model__regressor__n_neighbors=17, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.738 total time=   0.1s
# [CV 1/5] END model__regressor__n_neighbors=17, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.780 total time=   0.1s
# [CV 2/5] END model__regressor__n_neighbors=17, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.772 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=17, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.752 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=17, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.755 total time=   0.1s
# [CV 5/5] END model__regressor__n_neighbors=17, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.738 total time=   0.1s
# [CV 1/5] END model__regressor__n_neighbors=17, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.747 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=17, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.737 total time=   0.1s
# [CV 3/5] END model__regressor__n_neighbors=17, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.724 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=17, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.734 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=17, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.712 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=17, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.748 total time=   0.1s
# [CV 2/5] END model__regressor__n_neighbors=17, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.738 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=17, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.725 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=17, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.734 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=17, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.711 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=25, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.775 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=25, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.778 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=25, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.747 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=25, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.760 total time=   0.1s
# [CV 5/5] END model__regressor__n_neighbors=25, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.738 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=25, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.776 total time=   0.1s
# [CV 2/5] END model__regressor__n_neighbors=25, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.777 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=25, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.750 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=25, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.759 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=25, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.738 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=25, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.749 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=25, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.743 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=25, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.727 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=25, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.739 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=25, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.713 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=25, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.749 total time=   0.1s
# [CV 2/5] END model__regressor__n_neighbors=25, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.744 total time=   0.1s
# [CV 3/5] END model__regressor__n_neighbors=25, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.728 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=25, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.739 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=25, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.713 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=33, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.773 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=33, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.781 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=33, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.752 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=33, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.757 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=33, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.736 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=33, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.774 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=33, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.780 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=33, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.753 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=33, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.755 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=33, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.736 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=33, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.749 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=33, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.747 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=33, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.731 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=33, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.739 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=33, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.712 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=33, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.749 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=33, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.748 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=33, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.731 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=33, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.738 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=33, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.712 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=41, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.772 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=41, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.779 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=41, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.751 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=41, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.756 total time=   0.3s
# [CV 5/5] END model__regressor__n_neighbors=41, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.734 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=41, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.773 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=41, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.776 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=41, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.752 total time=   0.3s
# [CV 4/5] END model__regressor__n_neighbors=41, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.754 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=41, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.734 total time=   0.3s
# [CV 1/5] END model__regressor__n_neighbors=41, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.749 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=41, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.748 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=41, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.732 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=41, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.739 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=41, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.712 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=41, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.749 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=41, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.748 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=41, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.732 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=41, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.739 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=41, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.712 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=49, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.771 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=49, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.778 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=49, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.750 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=49, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.756 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=49, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.732 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=49, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.771 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=49, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.775 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=49, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.751 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=49, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.755 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=49, model__regressor__weights=uniform, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.731 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=49, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.750 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=49, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.748 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=49, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.733 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=49, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.740 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=49, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0;, score=0.712 total time=   0.2s
# [CV 1/5] END model__regressor__n_neighbors=49, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.749 total time=   0.2s
# [CV 2/5] END model__regressor__n_neighbors=49, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.748 total time=   0.2s
# [CV 3/5] END model__regressor__n_neighbors=49, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.732 total time=   0.2s
# [CV 4/5] END model__regressor__n_neighbors=49, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.740 total time=   0.2s
# [CV 5/5] END model__regressor__n_neighbors=49, model__regressor__weights=distance, preprocessors__num_distance__QuantReplace__threshold=0.01;, score=0.712 total time=   0.2s

# %% [markdown]
# Лучший Кандидат

# %%
Pipe_best=Pipe_GS.best_estimator_
Pipe_best
# Out:
# Pipeline(steps=[('preprocessors',
#                  ColumnTransformer(transformers=[('num_distance',
#                                                   Pipeline(steps=[('QuantReplace',
#                                                                    QuantileReplacer(threshold=0.01)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Distance']),
#                                                  ('num_engine',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Engine_capacity(cm3)']),
#                                                  ('num_year',
#                                                   Pipeline(steps=[('power',
#                                                                    PowerTransformer())]),
#                                                   ['Year'])])),
#                 ('model',
#                  TransformedTargetRegressor(regressor=KNeighborsRegressor(n_neighbors=np.int64(25)),
#                                             transformer=PowerTransformer()))])

# %%
Pipe_best.fit(X_train, y_train);

# %%
print(f"r2 на тренировочной выборке: {calculate_metric(Pipe_best, X_train, y_train):.4f}")
print(f"r2 на валидационной выборке: {calculate_metric(Pipe_best, X_val, y_val):.4f}")

print(f"mse на тренировочной выборке: {calculate_metric(Pipe_best, X_train, y_train, mse):.4f}")
print(f"mse на валидационной выборке: {calculate_metric(Pipe_best, X_val, y_val, mse):.4f}")
# Out:
# r2 на тренировочной выборке: 0.7672
# r2 на валидационной выборке: 0.7631
# mse на тренировочной выборке: 14157818.3589
# mse на валидационной выборке: 14914681.2051

# %% [markdown]
# ### Проанализируем результат
#
# На уровне гиперпараметров

# %%
DF_Pipe = pd.DataFrame(Pipe_GS.cv_results_)
DF_Pipe.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_model__regressor__n_neighbors',
#        'param_model__regressor__weights',
#        'param_preprocessors__num_distance__QuantReplace__threshold', 'params',
#        'split0_test_score', 'split1_test_score', 'split2_test_score',
#        'split3_test_score', 'split4_test_score', 'mean_test_score',
#        'std_test_score', 'rank_test_score'],
#       dtype='object')

# %%
DF_ = DF_Pipe[[ # берем только гиперпараметры,
       'param_model__regressor__n_neighbors',
       'param_model__regressor__weights',
       'param_preprocessors__num_distance__QuantReplace__threshold',
                 'mean_test_score', #среднее значение метрики на кросс-валидации
             'std_test_score', # разброс метрики на кросс-валидации
             'rank_test_score',# место
             ]]
cm = sns.light_palette("orange", as_cmap=True) # делаем расцветку по значению. В этот раз "50 оттенков Оранжевого"
hl = DF_.sort_values(by = 'rank_test_score').style.background_gradient(cmap=cm) # сортируем по убыванию места и раскрашиваем
hl
# Out:
# <style type="text/css">
# #T_6f48a_row0_col0, #T_6f48a_row3_col0, #T_6f48a_row10_col4, #T_6f48a_row13_col5, #T_6f48a_row18_col0, #T_6f48a_row19_col0 {
#   background-color: #f9ca77;
#   color: #000000;
# }
# #T_6f48a_row0_col2, #T_6f48a_row0_col3, #T_6f48a_row1_col3, #T_6f48a_row2_col2, #T_6f48a_row2_col3, #T_6f48a_row3_col3, #T_6f48a_row4_col2, #T_6f48a_row7_col2, #T_6f48a_row8_col0, #T_6f48a_row8_col4, #T_6f48a_row9_col0, #T_6f48a_row9_col2, #T_6f48a_row10_col2, #T_6f48a_row12_col0, #T_6f48a_row13_col0, #T_6f48a_row13_col2, #T_6f48a_row15_col2, #T_6f48a_row16_col2, #T_6f48a_row18_col2, #T_6f48a_row20_col2, #T_6f48a_row22_col2, #T_6f48a_row24_col2, #T_6f48a_row25_col2, #T_6f48a_row26_col5, #T_6f48a_row27_col5 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_6f48a_row0_col4, #T_6f48a_row4_col4 {
#   background-color: #fcb533;
#   color: #000000;
# }
# #T_6f48a_row0_col5, #T_6f48a_row1_col2, #T_6f48a_row3_col2, #T_6f48a_row5_col2, #T_6f48a_row6_col2, #T_6f48a_row8_col2, #T_6f48a_row11_col2, #T_6f48a_row12_col2, #T_6f48a_row14_col2, #T_6f48a_row17_col2, #T_6f48a_row19_col2, #T_6f48a_row21_col2, #T_6f48a_row22_col4, #T_6f48a_row23_col2, #T_6f48a_row24_col0, #T_6f48a_row25_col0, #T_6f48a_row26_col0, #T_6f48a_row26_col2, #T_6f48a_row26_col3, #T_6f48a_row27_col0, #T_6f48a_row27_col2, #T_6f48a_row27_col3 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# #T_6f48a_row1_col0, #T_6f48a_row2_col0, #T_6f48a_row16_col0, #T_6f48a_row17_col0 {
#   background-color: #fbbe4f;
#   color: #000000;
# }
# #T_6f48a_row1_col4, #T_6f48a_row11_col3 {
#   background-color: #fea90c;
#   color: #000000;
# }
# #T_6f48a_row1_col5 {
#   background-color: #f3ede6;
#   color: #000000;
# }
# #T_6f48a_row2_col4 {
#   background-color: #feaa11;
#   color: #000000;
# }
# #T_6f48a_row2_col5 {
#   background-color: #f4ebdd;
#   color: #000000;
# }
# #T_6f48a_row3_col4, #T_6f48a_row9_col4 {
#   background-color: #feac16;
#   color: #000000;
# }
# #T_6f48a_row3_col5 {
#   background-color: #f4e8d3;
#   color: #000000;
# }
# #T_6f48a_row4_col0, #T_6f48a_row6_col0, #T_6f48a_row20_col0, #T_6f48a_row21_col0 {
#   background-color: #f7d79f;
#   color: #000000;
# }
# #T_6f48a_row4_col3 {
#   background-color: #ffa501;
#   color: #000000;
# }
# #T_6f48a_row4_col5 {
#   background-color: #f5e5ca;
#   color: #000000;
# }
# #T_6f48a_row5_col0, #T_6f48a_row7_col0, #T_6f48a_row14_col0, #T_6f48a_row15_col0 {
#   background-color: #fdb127;
#   color: #000000;
# }
# #T_6f48a_row5_col3, #T_6f48a_row6_col3 {
#   background-color: #ffa602;
#   color: #000000;
# }
# #T_6f48a_row5_col4 {
#   background-color: #ffa808;
#   color: #000000;
# }
# #T_6f48a_row5_col5 {
#   background-color: #f5e2c1;
#   color: #000000;
# }
# #T_6f48a_row6_col4, #T_6f48a_row21_col5 {
#   background-color: #fdb32e;
#   color: #000000;
# }
# #T_6f48a_row6_col5 {
#   background-color: #f6dfb7;
#   color: #000000;
# }
# #T_6f48a_row7_col3 {
#   background-color: #ffa603;
#   color: #000000;
# }
# #T_6f48a_row7_col4, #T_6f48a_row12_col3 {
#   background-color: #fdb023;
#   color: #000000;
# }
# #T_6f48a_row7_col5 {
#   background-color: #f6dcaf;
#   color: #000000;
# }
# #T_6f48a_row8_col3 {
#   background-color: #ffa604;
#   color: #000000;
# }
# #T_6f48a_row8_col5 {
#   background-color: #f7d9a5;
#   color: #000000;
# }
# #T_6f48a_row9_col3 {
#   background-color: #ffa605;
#   color: #000000;
# }
# #T_6f48a_row9_col5 {
#   background-color: #f7d69c;
#   color: #000000;
# }
# #T_6f48a_row10_col0, #T_6f48a_row11_col0, #T_6f48a_row22_col0, #T_6f48a_row23_col0 {
#   background-color: #f5e4c7;
#   color: #000000;
# }
# #T_6f48a_row10_col3 {
#   background-color: #fea90b;
#   color: #000000;
# }
# #T_6f48a_row10_col5 {
#   background-color: #f8d393;
#   color: #000000;
# }
# #T_6f48a_row11_col4 {
#   background-color: #fac159;
#   color: #000000;
# }
# #T_6f48a_row11_col5 {
#   background-color: #f8d089;
#   color: #000000;
# }
# #T_6f48a_row12_col4 {
#   background-color: #f9c972;
#   color: #000000;
# }
# #T_6f48a_row12_col5 {
#   background-color: #f8cd80;
#   color: #000000;
# }
# #T_6f48a_row13_col3, #T_6f48a_row14_col3, #T_6f48a_row15_col3, #T_6f48a_row16_col3, #T_6f48a_row17_col3, #T_6f48a_row22_col5 {
#   background-color: #fdb024;
#   color: #000000;
# }
# #T_6f48a_row13_col4 {
#   background-color: #f9c971;
#   color: #000000;
# }
# #T_6f48a_row14_col4, #T_6f48a_row26_col4, #T_6f48a_row27_col4 {
#   background-color: #f9cb7a;
#   color: #000000;
# }
# #T_6f48a_row14_col5 {
#   background-color: #f9c86e;
#   color: #000000;
# }
# #T_6f48a_row15_col4 {
#   background-color: #f9c973;
#   color: #000000;
# }
# #T_6f48a_row15_col5 {
#   background-color: #fac565;
#   color: #000000;
# }
# #T_6f48a_row16_col4 {
#   background-color: #f9cb79;
#   color: #000000;
# }
# #T_6f48a_row16_col5 {
#   background-color: #fac25c;
#   color: #000000;
# }
# #T_6f48a_row17_col4 {
#   background-color: #f8cf87;
#   color: #000000;
# }
# #T_6f48a_row17_col5 {
#   background-color: #fbbf52;
#   color: #000000;
# }
# #T_6f48a_row18_col3, #T_6f48a_row19_col3 {
#   background-color: #fdb126;
#   color: #000000;
# }
# #T_6f48a_row18_col4 {
#   background-color: #f8d391;
#   color: #000000;
# }
# #T_6f48a_row18_col5 {
#   background-color: #fbbc49;
#   color: #000000;
# }
# #T_6f48a_row19_col4 {
#   background-color: #f7d598;
#   color: #000000;
# }
# #T_6f48a_row19_col5 {
#   background-color: #fcb940;
#   color: #000000;
# }
# #T_6f48a_row20_col3, #T_6f48a_row21_col3 {
#   background-color: #fdb32b;
#   color: #000000;
# }
# #T_6f48a_row20_col4 {
#   background-color: #f7d9a4;
#   color: #000000;
# }
# #T_6f48a_row20_col5, #T_6f48a_row23_col3 {
#   background-color: #fcb637;
#   color: #000000;
# }
# #T_6f48a_row21_col4 {
#   background-color: #f6deb6;
#   color: #000000;
# }
# #T_6f48a_row22_col3 {
#   background-color: #fcb636;
#   color: #000000;
# }
# #T_6f48a_row23_col4 {
#   background-color: #f3f0ed;
#   color: #000000;
# }
# #T_6f48a_row23_col5 {
#   background-color: #feae1b;
#   color: #000000;
# }
# #T_6f48a_row24_col3, #T_6f48a_row25_col3 {
#   background-color: #f3efec;
#   color: #000000;
# }
# #T_6f48a_row24_col4, #T_6f48a_row25_col4 {
#   background-color: #f3eee7;
#   color: #000000;
# }
# #T_6f48a_row24_col5, #T_6f48a_row25_col5 {
#   background-color: #feab12;
#   color: #000000;
# }
# </style>
# <table id="T_6f48a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f48a_level0_col0" class="col_heading level0 col0" >param_model__regressor__n_neighbors</th>
#       <th id="T_6f48a_level0_col1" class="col_heading level0 col1" >param_model__regressor__weights</th>
#       <th id="T_6f48a_level0_col2" class="col_heading level0 col2" >param_preprocessors__num_distance__QuantReplace__threshold</th>
#       <th id="T_6f48a_level0_col3" class="col_heading level0 col3" >mean_test_score</th>
#       <th id="T_6f48a_level0_col4" class="col_heading level0 col4" >std_test_score</th>
#       <th id="T_6f48a_level0_col5" class="col_heading level0 col5" >rank_test_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f48a_level0_row0" class="row_heading level0 row0" >13</th>
#       <td id="T_6f48a_row0_col0" class="data row0 col0" >25</td>
#       <td id="T_6f48a_row0_col1" class="data row0 col1" >uniform</td>
#       <td id="T_6f48a_row0_col2" class="data row0 col2" >0.010000</td>
#       <td id="T_6f48a_row0_col3" class="data row0 col3" >0.760078</td>
#       <td id="T_6f48a_row0_col4" class="data row0 col4" >0.015050</td>
#       <td id="T_6f48a_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6f48a_level0_row1" class="row_heading level0 row1" >16</th>
#       <td id="T_6f48a_row1_col0" class="data row1 col0" >33</td>
#       <td id="T_6f48a_row1_col1" class="data row1 col1" >uniform</td>
#       <td id="T_6f48a_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_6f48a_row1_col3" class="data row1 col3" >0.760030</td>
#       <td id="T_6f48a_row1_col4" class="data row1 col4" >0.015911</td>
#       <td id="T_6f48a_row1_col5" class="data row1 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6f48a_level0_row2" class="row_heading level0 row2" >17</th>
#       <td id="T_6f48a_row2_col0" class="data row2 col0" >33</td>
#       <td id="T_6f48a_row2_col1" class="data row2 col1" >uniform</td>
#       <td id="T_6f48a_row2_col2" class="data row2 col2" >0.010000</td>
#       <td id="T_6f48a_row2_col3" class="data row2 col3" >0.759678</td>

# %% [markdown]
# Небольшие выводы:
#
# * Предварительная обработка целевой переменной не так полезна, как для линейной модели ( метрики r2 на кроссвалидации осталась `0.76` , против роста с `0.49` до `0.56`)
#
# * предпочительней тип весов `uniform`, при этом стоит отметить разброс для типа весов `distance` не сильно меньше (по сравнению с ситуацией, когда мы не обрабатывали целевую переменную)
#
# * рост числа соседей после `17` не несет значительный вклад
#
# * в предварительной обработке не принципиально удалять редкие значения признаков или нет

# %% [markdown]
# # Про то как, Сохранять Модель

# %%
from joblib import dump, load # в scikit-learn ничего такого особенного нет
# пользуемся joblib

# %%
dump(model, 'model.joblib')  # чтобы сохранить объект
dump(kNNbest, 'best_knn.joblib')  # чтобы сохранить объект
dump(Pipe_best, 'Pipe_best_knn.joblib')  # чтобы сохранить объект
# Out:
# ['Pipe_best_knn.joblib']
